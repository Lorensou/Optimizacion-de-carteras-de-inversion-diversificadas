# %% [markdown]
# # PROYECTO CARTERAS DE INVERSIÓN

# %%
import pandas as pd
import numpy as np

# %%
# %pip install yfinance
import yfinance as yf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # SPAIN

# %% [markdown]
# ### IBEX 35

# %%
Ibex = yf.download(tickers='^IBEX', period='10y', interval='1d')

Ibex['datetime']=Ibex.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Ibex.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-10  8270.799805  8321.700195  8184.600098  8227.400391  8227.391602
# 2013-06-11  8179.600098  8182.500000  7980.100098  8089.299805  8089.291504
# 2013-06-12  8068.000000  8245.299805  8054.500000  8123.799805  8123.791504
# 2013-06-13  8039.500000  8098.100098  7958.600098  8071.700195  8071.691895
# 2013-06-14  8101.799805  8140.600098  8053.000000  8070.899902  8070.891602
#
#                Volume   datetime
# Date
# 2013-06-10  276422600 2013-06-10
# 2013-06-11  392860200 2013-06-11
# 2013-06-12  276164800 2013-06-12
# 2013-06-13  291659000 2013-06-13
# 2013-06-14  243709200 2013-06-14

# %%
Ibex.shape
# Out:
# (2558, 7)

# %% [markdown]
# # USA

# %% [markdown]
# ### STANDARD & POOR'S 500

# %%
SP500 = yf.download(tickers='^GSPC', period='10y', interval='1d')

SP500['datetime']=SP500.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
SP500.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-10  1644.670044  1648.689941  1639.260010  1642.810059  1642.810059
# 2013-06-11  1638.640015  1640.130005  1622.920044  1626.130005  1626.130005
# 2013-06-12  1629.939941  1637.709961  1610.920044  1612.520020  1612.520020
# 2013-06-13  1612.150024  1639.250000  1608.069946  1636.359985  1636.359985
# 2013-06-14  1635.520020  1640.800049  1623.959961  1626.729980  1626.729980
#
#                 Volume   datetime
# Date
# 2013-06-10  2978730000 2013-06-10
# 2013-06-11  3435710000 2013-06-11
# 2013-06-12  3202550000 2013-06-12
# 2013-06-13  3378620000 2013-06-13
# 2013-06-14  2939400000 2013-06-14

# %%
SP500.shape
# Out:
# (2517, 7)

# %% [markdown]
# ### DOW JONES INDUSTRIAL AVERAGE

# %%
DJ = yf.download(tickers='^DJI', period='10y', interval='1d')

DJ['datetime']=DJ.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
DJ.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2013-06-10  15247.809570  15300.639648  15211.250000  15238.589844
# 2013-06-11  15231.379883  15251.070312  15086.089844  15122.019531
# 2013-06-12  15130.389648  15241.280273  14981.209961  14995.230469
# 2013-06-13  14992.540039  15202.269531  14953.450195  15176.080078
# 2013-06-14  15178.080078  15205.919922  15044.799805  15070.179688
#
#                Adj Close     Volume   datetime
# Date
# 2013-06-10  15238.589844   94250000 2013-06-10
# 2013-06-11  15122.019531  101610000 2013-06-11
# 2013-06-12  14995.230469  105770000 2013-06-12
# 2013-06-13  15176.080078  104490000 2013-06-13
# 2013-06-14  15070.179688  107430000 2013-06-14

# %%
DJ.shape
# Out:
# (2517, 7)

# %% [markdown]
# # GLOBAL

# %% [markdown]
# ### NASDAQ COMPOSITE

# %%
NASDAQ_COMP = yf.download(tickers='^IXIC', period='10y', interval='1d')

NASDAQ_COMP['datetime']=NASDAQ_COMP.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
NASDAQ_COMP.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-10  3475.679932  3484.810059  3465.540039  3473.770020  3473.770020
# 2013-06-11  3436.620117  3466.570068  3426.570068  3436.949951  3436.949951
# 2013-06-12  3458.139893  3459.179932  3395.909912  3400.429932  3400.429932
# 2013-06-13  3398.540039  3451.030029  3387.610107  3445.360107  3445.360107
# 2013-06-14  3442.310059  3448.399902  3419.320068  3423.560059  3423.560059
#
#                 Volume   datetime
# Date
# 2013-06-10  1556520000 2013-06-10
# 2013-06-11  1560370000 2013-06-11
# 2013-06-12  1630200000 2013-06-12
# 2013-06-13  1584740000 2013-06-13
# 2013-06-14  1458030000 2013-06-14

# %%
NASDAQ_COMP.shape
# Out:
# (2517, 7)

# %% [markdown]
# ### NASDAQ 100 (TECH)

# %%
NASDAQ100 = yf.download(tickers='^NDX', period='10y', interval='1d')

NASDAQ100['datetime']=NASDAQ100.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
NASDAQ100.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-10  2995.030029  3004.669922  2985.500000  2990.489990  2990.489990
# 2013-06-11  2959.439941  2987.850098  2952.070068  2959.840088  2959.840088
# 2013-06-12  2977.679932  2978.760010  2921.879883  2926.139893  2926.139893
# 2013-06-13  2924.889893  2968.979980  2914.199951  2962.899902  2962.899902
# 2013-06-14  2958.870117  2966.129883  2939.679932  2943.860107  2943.860107
#
#                 Volume   datetime
# Date
# 2013-06-10  1556520000 2013-06-10
# 2013-06-11  1560370000 2013-06-11
# 2013-06-12  1630200000 2013-06-12
# 2013-06-13  1584740000 2013-06-13
# 2013-06-14  1458030000 2013-06-14

# %%
NASDAQ100.shape
# Out:
# (2517, 7)

# %% [markdown]
# # UK

# %% [markdown]
# ### FTSE

# %%
FTSE = yf.download(tickers='^FTSE', period='10y', interval='1d')

FTSE['datetime']=FTSE.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
FTSE.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-10  6412.000000  6421.200195  6379.600098  6400.500000  6400.500000
# 2013-06-11  6400.500000  6401.200195  6280.100098  6340.100098  6340.100098
# 2013-06-12  6340.100098  6364.299805  6295.899902  6299.500000  6299.500000
# 2013-06-13  6299.500000  6311.000000  6205.700195  6304.600098  6304.600098
# 2013-06-14  6304.600098  6343.500000  6290.600098  6308.299805  6308.299805
#
#                Volume   datetime
# Date
# 2013-06-10  597227000 2013-06-10
# 2013-06-11  736368300 2013-06-11
# 2013-06-12  693795800 2013-06-12
# 2013-06-13  824350700 2013-06-13
# 2013-06-14  734161700 2013-06-14

# %%
FTSE.shape
# Out:
# (2525, 7)

# %% [markdown]
# # FRANCE

# %% [markdown]
# ### CAC

# %%
CAC = yf.download(tickers='^FCHI', period='10y', interval='1d')

CAC['datetime']=CAC.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
CAC.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-10  3864.080078  3884.639893  3853.879883  3864.360107  3864.360107
# 2013-06-11  3847.000000  3849.360107  3780.389893  3810.560059  3810.560059
# 2013-06-12  3805.149902  3835.489990  3791.709961  3793.699951  3793.699951
# 2013-06-13  3747.649902  3804.250000  3731.840088  3797.979980  3797.979980
# 2013-06-14  3823.199951  3830.689941  3793.500000  3805.159912  3805.159912
#
#                Volume   datetime
# Date
# 2013-06-10   67885400 2013-06-10
# 2013-06-11  106952600 2013-06-11
# 2013-06-12   82900600 2013-06-12
# 2013-06-13  104036400 2013-06-13
# 2013-06-14   77729800 2013-06-14

# %%
CAC.shape
# Out:
# (2560, 7)

# %% [markdown]
# # EUROPE

# %% [markdown]
# ### EUROSTOXX 50

# %%
EUROSTOXX50 = yf.download(tickers='^STOXX50E', period='10y', interval='1d')

EUROSTOXX50['datetime']=EUROSTOXX50.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
EUROSTOXX50.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-10  2719.179932  2734.290039  2708.719971  2719.399902  2719.399902
# 2013-06-11  2707.129883  2707.129883  2656.000000  2683.199951  2683.199951
# 2013-06-12  2681.379883  2701.219971  2663.889893  2666.520020  2666.520020
# 2013-06-13  2647.659912  2666.489990  2617.479980  2661.709961  2661.709961
# 2013-06-14  2670.610107  2687.189941  2660.979980  2667.320068  2667.320068
#
#             Volume   datetime
# Date
# 2013-06-10       0 2013-06-10
# 2013-06-11       0 2013-06-11
# 2013-06-12       0 2013-06-12
# 2013-06-13       0 2013-06-13
# 2013-06-14       0 2013-06-14

# %%
EUROSTOXX50.shape
# Out:
# (2509, 7)

# %% [markdown]
# # GERMANY

# %% [markdown]
# ### GDA

# %%
GDA = yf.download(tickers='^GDAXI', period='10y', interval='1d')

GDA['datetime']=GDA.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
GDA.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-10  8246.040039  8355.790039  8245.940430  8307.690430  8307.690430
# 2013-06-11  8256.190430  8260.860352  8141.020020  8222.459961  8222.459961
# 2013-06-12  8204.910156  8246.080078  8122.720215  8143.270020  8143.270020
# 2013-06-13  8023.370117  8110.379883  7968.129883  8095.390137  8095.390137
# 2013-06-14  8157.879883  8188.000000  8111.379883  8127.959961  8127.959961
#
#               Volume   datetime
# Date
# 2013-06-10  75733100 2013-06-10
# 2013-06-11  96689800 2013-06-11
# 2013-06-12  81793400 2013-06-12
# 2013-06-13  97586800 2013-06-13
# 2013-06-14  72768100 2013-06-14

# %%
GDA.shape
# Out:
# (2533, 7)

# %% [markdown]
# # JAPAN

# %% [markdown]
# ### NIKKEI 225

# %%
NIKKEI225 = yf.download(tickers='^N225', period='10y', interval='1d')

NIKKEI225['datetime']=NIKKEI225.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
NIKKEI225.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2013-06-10  13141.849609  13514.200195  13141.370117  13514.200195
# 2013-06-11  13504.769531  13584.309570  13296.309570  13317.620117
# 2013-06-12  13087.660156  13332.719727  12994.080078  13289.320312
# 2013-06-13  13038.019531  13050.110352  12415.849609  12445.379883
# 2013-06-14  12668.900391  12900.650391  12629.309570  12686.519531
#
#                Adj Close     Volume   datetime
# Date
# 2013-06-10  13514.200195  241400000 2013-06-10
# 2013-06-11  13317.620117  260200000 2013-06-11
# 2013-06-12  13289.320312  205500000 2013-06-12
# 2013-06-13  12445.379883  240900000 2013-06-13
# 2013-06-14  12686.519531  278200000 2013-06-14

# %%
NIKKEI225.shape
# Out:
# (2444, 7)

# %% [markdown]
# # INDIA

# %% [markdown]
# ### NIFTY 50

# %%
NIFTY50 = yf.download(tickers='^NSEI', period='10y', interval='1d')

NIFTY50['datetime']=NIFTY50.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
NIFTY50.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-10  5907.899902  5931.649902  5857.399902  5878.000000  5878.000000
# 2013-06-11  5848.750000  5868.049805  5780.350098  5788.799805  5788.799805
# 2013-06-12  5771.750000  5792.899902  5738.600098  5760.200195  5760.200195
# 2013-06-13  5709.350098  5729.850098  5683.100098  5699.100098  5699.100098
# 2013-06-14  5748.950195  5819.399902  5739.399902  5808.399902  5808.399902
#
#             Volume   datetime
# Date
# 2013-06-10  100100 2013-06-10
# 2013-06-11  180900 2013-06-11
# 2013-06-12  140400 2013-06-12
# 2013-06-13  142000 2013-06-13
# 2013-06-14  124400 2013-06-14

# %%
NIFTY50.shape
# Out:
# (2454, 7)

# %% [markdown]
# # HONG KONG

# %% [markdown]
# ### HANG SENG INDEX

# %%
HANGSENG = yf.download(tickers='^HSI', period='10y', interval='1d')

HANGSENG['datetime']=HANGSENG.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
HANGSENG.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2013-06-10  21592.900391  21723.859375  21497.550781  21615.089844
# 2013-06-11  21542.300781  21632.009766  21307.990234  21354.660156
# 2013-06-13  21069.259766  21069.259766  20652.750000  20887.039062
# 2013-06-14  21083.410156  21164.679688  20954.660156  20969.140625
# 2013-06-17  21007.279297  21272.750000  21007.279297  21225.900391
#
#                Adj Close      Volume   datetime
# Date
# 2013-06-10  21615.089844  1464580800 2013-06-10
# 2013-06-11  21354.660156  2121919200 2013-06-11
# 2013-06-13  20887.039062  3299557200 2013-06-13
# 2013-06-14  20969.140625  2394670200 2013-06-14
# 2013-06-17  21225.900391  1879428800 2013-06-17

# %%
HANGSENG.shape
# Out:
# (2462, 7)

# %% [markdown]
# # ESTANDARIZAR FECHAS

# %%
print(Ibex.shape)
print(SP500.shape)
print(DJ.shape)
print(NASDAQ_COMP.shape)
print(NASDAQ100.shape)
print(FTSE.shape)
print(CAC.shape)
print(EUROSTOXX50.shape)
print(GDA.shape)
print(NIKKEI225.shape)
print(NIFTY50.shape)
print(HANGSENG.shape)
# Out:
# (2558, 7)
# (2517, 7)
# (2517, 7)
# (2517, 7)
# (2517, 7)
# (2525, 7)
# (2560, 7)
# (2509, 7)
# (2533, 7)
# (2444, 7)
# (2454, 7)
# (2462, 7)

# %%
print('Ibex first' , Ibex.index[0])
print('Ibex last' , Ibex.index[-1])
print('SP500 first' , SP500.index[0])
print('SP500 last' , SP500.index[-1])
print('Dow Jones first' , DJ.index[0])
print('Dow Jones last' , DJ.index[-1])
print('NASDAQ_COMP first' , NASDAQ_COMP.index[0])
print('NASDAQ_COMP last' , NASDAQ_COMP.index[-1])
print('NASDAQ100 first' , NASDAQ100.index[0])
print('NASDAQ100 last' , NASDAQ100.index[-1])
print('FTSE first' , FTSE.index[0])
print('FTSE last' , FTSE.index[-1])
print('CAC first' , CAC.index[0])
print('CAC last' , CAC.index[-1])
print('EUROSTOXX50 first' , EUROSTOXX50.index[0])
print('EUROSTOXX50 last' , EUROSTOXX50.index[-1])
print('GDA first' , GDA.index[0])
print('GDA last' , GDA.index[-1])
print('NIKKEI225 first' , NIKKEI225.index[0])
print('NIKKEI225 last' , NIKKEI225.index[-1])
print('NIFTY50 first' , NIFTY50.index[0])
print('NIFTY50 last' , NIFTY50.index[-1])
print('HANGSENG first' , HANGSENG.index[0])
print('HANGSENG last' , HANGSENG.index[-1])
# Out:
# Ibex first 2013-06-10 00:00:00
# Ibex last 2023-06-08 00:00:00
# SP500 first 2013-06-10 00:00:00
# SP500 last 2023-06-07 00:00:00
# Dow Jones first 2013-06-10 00:00:00
# Dow Jones last 2023-06-07 00:00:00
# NASDAQ_COMP first 2013-06-10 00:00:00
# NASDAQ_COMP last 2023-06-07 00:00:00
# NASDAQ100 first 2013-06-10 00:00:00
# NASDAQ100 last 2023-06-07 00:00:00
# FTSE first 2013-06-10 00:00:00
# FTSE last 2023-06-08 00:00:00
# CAC first 2013-06-10 00:00:00
# CAC last 2023-06-08 00:00:00
# EUROSTOXX50 first 2013-06-10 00:00:00
# EUROSTOXX50 last 2023-06-08 00:00:00
# GDA first 2013-06-10 00:00:00
# GDA last 2023-06-08 00:00:00
# NIKKEI225 first 2013-06-10 00:00:00
# NIKKEI225 last 2023-06-08 00:00:00
# NIFTY50 first 2013-06-10 00:00:00
# NIFTY50 last 2023-06-08 00:00:00
# HANGSENG first 2013-06-10 00:00:00
# HANGSENG last 2023-06-08 00:00:00

# %%
# Para empezar vamos a quedarnos con las columnas de indice(fecha) y de ajuste cierre del dia de cada uno de los indices porque son los datos que realmente nos interesan.

# Nos quedamos con el valor de ajuste de cierre ya que es un indicador más coherente para lo que queremos ver.

# %%
import matplotlib.pyplot as plt

## Para graficar la evolución de los índices y hacerme una idea que tendencia siguen.

# %%
Ibex  = Ibex.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
Ibex = Ibex.rename(columns={'Adj Close': 'Ibex_35'})
Ibex.head()
# Out:
#                 Ibex_35
# Date
# 2013-06-10  8227.391602
# 2013-06-11  8089.291504
# 2013-06-12  8123.791504
# 2013-06-13  8071.691895
# 2013-06-14  8070.891602

# %%
Ibex.plot(y='Ibex_35');

# %%
SP500  = SP500.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
SP500 = SP500.rename(columns={'Adj Close': 'S&P_500'})
SP500.head()
# Out:
#                 S&P_500
# Date
# 2013-06-10  1642.810059
# 2013-06-11  1626.130005
# 2013-06-12  1612.520020
# 2013-06-13  1636.359985
# 2013-06-14  1626.729980

# %%
SP500.plot(y='S&P_500');

# %%
DJ  = DJ.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
DJ = DJ.rename(columns={'Adj Close': 'Dow_Jones'})
DJ.head()
# Out:
#                Dow_Jones
# Date
# 2013-06-10  15238.589844
# 2013-06-11  15122.019531
# 2013-06-12  14995.230469
# 2013-06-13  15176.080078
# 2013-06-14  15070.179688

# %%
DJ.plot(y='Dow_Jones');

# %%
NASDAQ_COMP  = NASDAQ_COMP.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
NASDAQ_COMP = NASDAQ_COMP.rename(columns={'Adj Close': 'NASDAQ_Composite'})
NASDAQ_COMP.head()
# Out:
#             NASDAQ_Composite
# Date
# 2013-06-10       3473.770020
# 2013-06-11       3436.949951
# 2013-06-12       3400.429932
# 2013-06-13       3445.360107
# 2013-06-14       3423.560059

# %%
NASDAQ_COMP.plot(y='NASDAQ_Composite');

# %%
NASDAQ100  = NASDAQ100.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
NASDAQ100 = NASDAQ100.rename(columns={'Adj Close': 'NASDAQ_100'})
NASDAQ100.head()
# Out:
#              NASDAQ_100
# Date
# 2013-06-10  2990.489990
# 2013-06-11  2959.840088
# 2013-06-12  2926.139893
# 2013-06-13  2962.899902
# 2013-06-14  2943.860107

# %%
NASDAQ100.plot(y='NASDAQ_100');

# %%
FTSE  = FTSE.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
FTSE = FTSE.rename(columns={'Adj Close': 'FTSE'})
FTSE.head()
# Out:
#                    FTSE
# Date
# 2013-06-10  6400.500000
# 2013-06-11  6340.100098
# 2013-06-12  6299.500000
# 2013-06-13  6304.600098
# 2013-06-14  6308.299805

# %%
FTSE.plot(y='FTSE');

# %%
CAC  = CAC.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
CAC = CAC.rename(columns={'Adj Close': 'CAC'})
CAC.head()
# Out:
#                     CAC
# Date
# 2013-06-10  3864.360107
# 2013-06-11  3810.560059
# 2013-06-12  3793.699951
# 2013-06-13  3797.979980
# 2013-06-14  3805.159912

# %%
CAC.plot(y = 'CAC');

# %%
EUROSTOXX50  = EUROSTOXX50.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
EUROSTOXX50 = EUROSTOXX50.rename(columns={'Adj Close': 'EURO_STOXX_50'})
EUROSTOXX50.head()
# Out:
#             EURO_STOXX_50
# Date
# 2013-06-10    2719.399902
# 2013-06-11    2683.199951
# 2013-06-12    2666.520020
# 2013-06-13    2661.709961
# 2013-06-14    2667.320068

# %%
EUROSTOXX50.plot(y= 'EURO_STOXX_50');

# %%
GDA  = GDA.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
GDA = GDA.rename(columns={'Adj Close': 'GDA'})
GDA.head()
# Out:
#                     GDA
# Date
# 2013-06-10  8307.690430
# 2013-06-11  8222.459961
# 2013-06-12  8143.270020
# 2013-06-13  8095.390137
# 2013-06-14  8127.959961

# %%
GDA.plot( y = 'GDA');

# %%
NIKKEI225  = NIKKEI225.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
NIKKEI225 = NIKKEI225.rename(columns={'Adj Close': 'NIKKEI_225'})
NIKKEI225.head()
# Out:
#               NIKKEI_225
# Date
# 2013-06-10  13514.200195
# 2013-06-11  13317.620117
# 2013-06-12  13289.320312
# 2013-06-13  12445.379883
# 2013-06-14  12686.519531

# %%
NIKKEI225.plot(y = 'NIKKEI_225');

# %%
NIFTY50  = NIFTY50.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
NIFTY50 = NIFTY50.rename(columns={'Adj Close': 'NIFTY_50'})
NIFTY50.head()
# Out:
#                NIFTY_50
# Date
# 2013-06-10  5878.000000
# 2013-06-11  5788.799805
# 2013-06-12  5760.200195
# 2013-06-13  5699.100098
# 2013-06-14  5808.399902

# %%
NIFTY50.plot( y = 'NIFTY_50');

# %%
HANGSENG  = HANGSENG.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
HANGSENG = HANGSENG.rename(columns={'Adj Close': 'HANG_SENG_Index'})
HANGSENG.head()
# Out:
#             HANG_SENG_Index
# Date
# 2013-06-10     21615.089844
# 2013-06-11     21354.660156
# 2013-06-13     20887.039062
# 2013-06-14     20969.140625
# 2013-06-17     21225.900391

# %%
HANGSENG.plot( y = 'HANG_SENG_Index');

# %% [markdown]
# ## Hacemos un Join para tener las cotizaciones de los indices en un df.

# %%
indices = [Ibex, SP500, DJ, NASDAQ_COMP, NASDAQ100, FTSE, CAC, EUROSTOXX50, GDA, NIKKEI225, NIFTY50, HANGSENG]

# %%
df = Ibex

# %%
for i in indices[1:]:
    df = df.join(i, how='inner')

print(df)
# Out:
#                 Ibex_35      S&P_500     Dow_Jones  NASDAQ_Composite  \
# Date
# 2013-06-10  8227.391602  1642.810059  15238.589844       3473.770020
# 2013-06-11  8089.291504  1626.130005  15122.019531       3436.949951
# 2013-06-13  8071.691895  1636.359985  15176.080078       3445.360107
# 2013-06-14  8070.891602  1626.729980  15070.179688       3423.560059
# 2013-06-17  8136.291504  1639.040039  15179.849609       3452.129883
# ...                 ...          ...           ...               ...
# 2023-06-01  9167.500000  4221.020020  33061.570312      13100.980469
# 2023-06-02  9317.299805  4282.370117  33762.761719      13240.769531
# 2023-06-05  9289.099609  4273.790039  33562.859375      13229.429688
# 2023-06-06  9310.799805  4283.850098  33573.281250      13276.419922
# 2023-06-07  9359.799805  4267.520020  33665.019531      13104.900391
#
#               NASDAQ_100         FTSE          CAC  EURO_STOXX_50  \
# Date
# ...

# %%
df.head()
# Out:
#                 Ibex_35      S&P_500     Dow_Jones  NASDAQ_Composite  \
# Date
# 2013-06-10  8227.391602  1642.810059  15238.589844       3473.770020
# 2013-06-11  8089.291504  1626.130005  15122.019531       3436.949951
# 2013-06-13  8071.691895  1636.359985  15176.080078       3445.360107
# 2013-06-14  8070.891602  1626.729980  15070.179688       3423.560059
# 2013-06-17  8136.291504  1639.040039  15179.849609       3452.129883
#
#              NASDAQ_100         FTSE          CAC  EURO_STOXX_50          GDA  \
# Date
# 2013-06-10  2990.489990  6400.500000  3864.360107    2719.399902  8307.690430
# 2013-06-11  2959.840088  6340.100098  3810.560059    2683.199951  8222.459961
# 2013-06-13  2962.899902  6304.600098  3797.979980    2661.709961  8095.390137
# 2013-06-14  2943.860107  6308.299805  3805.159912    2667.320068  8127.959961
# 2013-06-17  2971.260010  6330.500000  3863.659912    2702.689941  8215.730469
#
#               NIKKEI_225     NIFTY_50  HANG_SENG_Index
# Date
# ...

# %%
df.shape   #Al hacer el inner join hemos perdido algunos días ya que no todas las bolsas operan los mismos dias del año.
# Out:
# (2086, 12)

# %% [markdown]
# ## Visualizamos la evolución de todos los índices en un gráfico de lineas temporales.

# %%
df.plot( y=['Ibex_35', 'S&P_500', 'Dow_Jones', 'NASDAQ_Composite', 'NASDAQ_100', 'FTSE', 'CAC', 'EURO_STOXX_50', 'GDA', 'NIKKEI_225', 'NIFTY_50', 'HANG_SENG_Index'], kind='line', figsize = (25, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## invertir indice para tener los valores actuales primero

# %%
df = df.sort_index(ascending = False)
df.head()
# Out:
#                 Ibex_35      S&P_500     Dow_Jones  NASDAQ_Composite  \
# Date
# 2023-06-07  9359.799805  4267.520020  33665.019531      13104.900391
# 2023-06-06  9310.799805  4283.850098  33573.281250      13276.419922
# 2023-06-05  9289.099609  4273.790039  33562.859375      13229.429688
# 2023-06-02  9317.299805  4282.370117  33762.761719      13240.769531
# 2023-06-01  9167.500000  4221.020020  33061.570312      13100.980469
#
#               NASDAQ_100         FTSE          CAC  EURO_STOXX_50  \
# Date
# 2023-06-07  14303.290039  7624.299805  7202.790039    4291.910156
# 2023-06-06  14558.089844  7628.100098  7209.000000    4295.220215
# 2023-06-05  14556.500000  7600.000000  7200.910156    4293.240234
# 2023-06-02  14546.639648  7607.299805  7270.689941    4323.520020
# 2023-06-01  14441.509766  7490.299805  7137.430176    4257.609863
#
#                      GDA    NIKKEI_225      NIFTY_50  HANG_SENG_Index
# Date
# ...

# %% [markdown]
# # RENTABILIDAD

# %%
#df.head()

# %%
#df.shape
#d_por_año = 2086/10
#d_por_año

# %%
#comprb = df.pct_change(periods=-208)
#comprb.head()

# %%
#df[208:]

# %%
#comprb.info()

# %%
#nulos = 2086 - 1878
#nulos

# %% [markdown]
# ### Para ser más exactos en el calculo de rentabilidades y riesgo medios anuales los voy a calcular por separado(dado que hay índices en los que sus bolsas han operado más/menos/distintos días) y luego mergearlos en un df.

# %%
print('ibex', Ibex.shape)
print('sp', SP500.shape)
print('dj', DJ.shape)
print('nasdaq_comp', NASDAQ_COMP.shape)
print('nasdaq100', NASDAQ100.shape)
print('ftse', FTSE.shape)
print('cac', CAC.shape)
print('eurostox', EUROSTOXX50.shape)
print('gda', GDA.shape)
print('nikkey', NIKKEI225.shape)
print('nifty', NIFTY50.shape)
print('hangseng', HANGSENG.shape)
# Out:
# ibex (2558, 1)
# sp (2517, 1)
# dj (2517, 1)
# nasdaq_comp (2517, 1)
# nasdaq100 (2517, 1)
# ftse (2525, 1)
# cac (2560, 1)
# eurostox (2509, 1)
# gda (2533, 1)
# nikkey (2444, 1)
# nifty (2454, 1)
# hangseng (2462, 1)

# %% [markdown]
# ### Calculamos la rentabilidad anual diariamente. Posteriormente hacemos el promedio.

# %%
d_por_año = 2558/10
d_por_año              #para luego aplicar al peridodo de la función .pct_change y nos compare bien los precios con los de año anterior, este número tambien representa los días/año que ha estado abierta la bolsa en la que opera el índice (en el caso del Ibex).
# Out:
# 255.8

# %%
r_Ibex = Ibex['Ibex_35'].pct_change(periods= 255) 

rent_Ibex = r_Ibex.mean()

print(rent_Ibex)
r_Ibex
# Out:
# 0.0004874164766911974
# Date
# 2013-06-10         NaN
# 2013-06-11         NaN
# 2013-06-12         NaN
# 2013-06-13         NaN
# 2013-06-14         NaN
#                 ...
# 2023-06-02    0.054435
# 2023-06-05    0.050613
# 2023-06-06    0.052936
# 2023-06-07    0.074456
# 2023-06-08    0.122804
# Name: Ibex_35, Length: 2558, dtype: float64

# %%
ibex_log = np.log(Ibex).diff(255)
ibex_log
# Out:
#              Ibex_35
# Date
# 2013-06-10       NaN
# 2013-06-11       NaN
# 2013-06-12       NaN
# 2013-06-13       NaN
# 2013-06-14       NaN
# ...              ...
# 2023-06-02  0.053005
# 2023-06-05  0.049374
# 2023-06-06  0.051583
# 2023-06-07  0.071814
# 2023-06-08  0.115829
#
# [2558 rows x 1 columns]

# %%
r_Ibex.info() #Perfecto, solo tenemos el 2013 de nulos ya que no puede compararlo con el año anterior.
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 2558 entries, 2013-06-10 to 2023-06-08
# Series name: Ibex_35
# Non-Null Count  Dtype
# --------------  -----
# 2303 non-null   float64
# dtypes: float64(1)
# memory usage: 104.5 KB

# %%
r_SP500 = SP500['S&P_500'].pct_change(periods= 251) 

rent_SP500 = r_SP500.mean()

rent_SP500
# Out:
# 0.10159959085344

# %%
r_DJ = DJ['Dow_Jones'].pct_change(periods= 251) 

rent_DJ = r_DJ.mean()

rent_DJ
# Out:
# 0.0902353668988002

# %%
r_NASDAQ_COMP = NASDAQ_COMP['NASDAQ_Composite'].pct_change(periods= 251) 

rent_NASDAQ_COMP = r_NASDAQ_COMP.mean()

rent_NASDAQ_COMP
# Out:
# 0.1441188654186968

# %%
r_NASDAQ100 = NASDAQ100['NASDAQ_100'].pct_change(periods= 251) 

rent_NASDAQ100 = r_NASDAQ100.mean()

rent_NASDAQ100
# Out:
# 0.16950091135758

# %%
r_FTSE = FTSE['FTSE'].pct_change(periods= 252) 

rent_FTSE = r_FTSE.mean()

rent_FTSE
# Out:
# 0.019595182186410674

# %%
r_CAC = CAC['CAC'].pct_change(periods= 256) 

rent_CAC = r_CAC.mean()

rent_CAC
# Out:
# 0.06225116670212077

# %%
r_EUROSTOXX50 = EUROSTOXX50['EURO_STOXX_50'].pct_change(periods= 250) 

rent_EUROSTOXX50 = r_EUROSTOXX50.mean()

rent_EUROSTOXX50
# Out:
# 0.03963685157195398

# %%
r_GDA = GDA['GDA'].pct_change(periods= 253) 

rent_GDA = r_GDA.mean()

rent_GDA
# Out:
# 0.06257964353126333

# %%
r_NIKKEI225 = NIKKEI225['NIKKEI_225'].pct_change(periods= 244) 

rent_NIKKEI225 = r_NIKKEI225.mean()

rent_NIKKEI225
# Out:
# 0.08561560885163051

# %%
r_NIFTY50 = NIFTY50['NIFTY_50'].pct_change(periods= 245) 

rent_NIFTY50 = r_NIFTY50.mean()

rent_NIFTY50
# Out:
# 0.13613847250281721

# %%
r_HANGSENG = HANGSENG['HANG_SENG_Index'].pct_change(periods= 246) 

rent_HANGSENG = r_HANGSENG.mean()

rent_HANGSENG
# Out:
# -0.00156245428270048

# %%
column_names = ['Ibex', 'S&P', 'DJ', 'NASDAQ_COMP', 'NASDAQ_100', 'FTSE', 'CAC', 'EUSTOXX', 'GDA', 'NIKKEI', 'NIFTY', 'HANGSENG']
values = [rent_Ibex, rent_SP500, rent_DJ, rent_NASDAQ_COMP, rent_NASDAQ100, rent_FTSE, rent_CAC, rent_EUROSTOXX50, rent_GDA, rent_NIKKEI225, rent_NIFTY50, rent_HANGSENG]

ROI_STD = pd.DataFrame(columns=column_names, data=[values])
ROI_STD
# Out:
#        Ibex     S&P        DJ  NASDAQ_COMP  NASDAQ_100      FTSE       CAC  \
# 0  0.000487  0.1016  0.090235     0.144119    0.169501  0.019595  0.062251
#
#     EUSTOXX      GDA    NIKKEI     NIFTY  HANGSENG
# 0  0.039637  0.06258  0.085616  0.136138 -0.001562

# %% [markdown]
# ## Riesgo

# %% [markdown]
# #### Calculo la desviación estándar de las rentabilidades anuales diarias de cada índice.

# %%
std_Ibex = r_Ibex.std()
std_Ibex
# Out:
# 0.16042877342117778

# %%
std_SP500 = r_SP500.std()
std_SP500
# Out:
# 0.1339971775768312

# %%
std_DJ = r_DJ.std()
std_DJ
# Out:
# 0.12585099030655061

# %%
std_NASDAQ_COMP = r_NASDAQ_COMP.std()
std_NASDAQ_COMP
# Out:
# 0.19473630436932618

# %%
std_NASDAQ100 = r_NASDAQ100.std()
std_NASDAQ100
# Out:
# 0.19319071447818106

# %%
std_FTSE = r_FTSE.std()
std_FTSE
# Out:
# 0.10841240530051825

# %%
std_CAC = r_CAC.std()
std_CAC
# Out:
# 0.146088268638503

# %%
std_EUROSTOXX50 = r_EUROSTOXX50.std()
std_EUROSTOXX50
# Out:
# 0.14538243761992836

# %%
std_GDA = r_GDA.std()
std_GDA
# Out:
# 0.15087438211565427

# %%
std_NIKKEI225 = r_NIKKEI225.std()
std_NIKKEI225
# Out:
# 0.15741066476206192

# %%
std_NIFTY50 = r_NIFTY50.std()
std_NIFTY50
# Out:
# 0.17974363681849345

# %%
std_HANGSENG = r_HANGSENG.std()
std_HANGSENG
# Out:
# 0.16559348633308285

# %%
std = [std_Ibex, std_SP500, std_DJ, std_NASDAQ_COMP, std_NASDAQ100, std_FTSE, std_CAC, std_EUROSTOXX50, std_GDA, std_NIKKEI225, std_NIFTY50, std_HANGSENG]

# %%
ROI_STD = pd.DataFrame(columns=column_names, data=[values, std])
ROI_STD
# Out:
#        Ibex       S&P        DJ  NASDAQ_COMP  NASDAQ_100      FTSE       CAC  \
# 0  0.000487  0.101600  0.090235     0.144119    0.169501  0.019595  0.062251
# 1  0.160429  0.133997  0.125851     0.194736    0.193191  0.108412  0.146088
#
#     EUSTOXX       GDA    NIKKEI     NIFTY  HANGSENG
# 0  0.039637  0.062580  0.085616  0.136138 -0.001562
# 1  0.145382  0.150874  0.157411  0.179744  0.165593

# %%
df_transposed = ROI_STD.transpose()
df_transposed
# Out:
#                     0         1
# Ibex         0.000487  0.160429
# S&P          0.101600  0.133997
# DJ           0.090235  0.125851
# NASDAQ_COMP  0.144119  0.194736
# NASDAQ_100   0.169501  0.193191
# FTSE         0.019595  0.108412
# CAC          0.062251  0.146088
# EUSTOXX      0.039637  0.145382
# GDA          0.062580  0.150874
# NIKKEI       0.085616  0.157411
# NIFTY        0.136138  0.179744
# HANGSENG    -0.001562  0.165593

# %%
df_transposed = df_transposed.rename(columns={0: 'Rentabilidad promedio', 1: 'Volatilidad'})
df_transposed
# Out:
#              Rentabilidad promedio  Volatilidad
# Ibex                      0.000487     0.160429
# S&P                       0.101600     0.133997
# DJ                        0.090235     0.125851
# NASDAQ_COMP               0.144119     0.194736
# NASDAQ_100                0.169501     0.193191
# FTSE                      0.019595     0.108412
# CAC                       0.062251     0.146088
# EUSTOXX                   0.039637     0.145382
# GDA                       0.062580     0.150874
# NIKKEI                    0.085616     0.157411
# NIFTY                     0.136138     0.179744
# HANGSENG                 -0.001562     0.165593

# %% [markdown]
# ## Genero 100K carteras aleatorias

# %%
import random


def generar_carteras_aleatorias(titulos, n_carteras):
    rendimientos = [random.uniform(0, 0.36) for _ in range(len(titulos))]
    volatilidades = [random.uniform(0, 0.60) for _ in range(len(titulos))]
    carteras_aleatorias = []
    
    for _ in range(n_carteras):
        pesos = [random.uniform(0, 1) for _ in range(len(titulos))]
        suma_pesos = sum(pesos)
        pesos_normalizados = [peso / suma_pesos for peso in pesos]
        
        # Calcular el rendimiento y la volatilidad de la cartera actual
        rendimiento = np.dot(pesos_normalizados, rendimientos)
        volatilidad = np.sqrt(np.dot(pesos_normalizados, np.multiply(volatilidades, volatilidades)))
        
        carteras_aleatorias.append({'Rendimiento': rendimiento , 'Volatilidad': volatilidad})
    
    df_carteras = pd.DataFrame(carteras_aleatorias)
    
    return df_carteras

# %%
titulos = ['Ibex', 'S&P', 'DJ', 'NASDAQ_COMP', 'NASDAQ_100', 'FTSE', 'CAC', 'EUSTOXX', 'GDA', 'NIKKEI', 'NIFTY', 'HANGSENG']
n_carteras = 100000

carteras_aleatorias = generar_carteras_aleatorias(titulos, n_carteras)

carteras_aleatorias
# Out:
#        Rendimiento  Volatilidad
# 0         0.142640     0.394580
# 1         0.165388     0.389261
# 2         0.141499     0.388061
# 3         0.165054     0.404627
# 4         0.161292     0.398975
# ...            ...          ...
# 99995     0.121556     0.420866
# 99996     0.145565     0.396747
# 99997     0.203398     0.367371
# 99998     0.153832     0.421148
# 99999     0.188973     0.377354
#
# [100000 rows x 2 columns]

# %%
#carteras_aleatorias.to_excel("C:/Users/Lorenzo/Desktop/Proyecto Final MARKOVITZ/carteras_aleatorias.xlsx", index=True)

# %%
from  Mis_funciones import *

# %%
FronEfi = frontera_eficiente(df_transposed['Rentabilidad promedio'], df_transposed['Volatilidad'])
FronEfi
# Out:
#      Rendimiento  Volatilidad  \
# 0       0.169501     0.439535
# 1       0.169501     0.439535
# 2       0.169501     0.439535
# 3       0.169501     0.439535
# 4       0.169501     0.439535
# ..           ...          ...
# 495     0.082448     0.114719
# 496     0.082298     0.114650
# 497     0.082149     0.114583
# 498     0.082002     0.114518
# 499     0.081858     0.114454
#
#                                          Pesos Cartera
# 0    {'Ibex': 3.365445282520118e-24, 'S&P': 3.33116...
# 1    {'Ibex': 1.1699972998605228e-22, 'S&P': 5.9427...
# 2    {'Ibex': 8.557770021750794e-25, 'S&P': 8.20599...
# 3    {'Ibex': 1.092506391077326e-22, 'S&P': 5.37038...
# 4    {'Ibex': 1.1189975633634218e-22, 'S&P': 5.6352...
# ..                                                 ...
# 495  {'Ibex': 0.05503479294364408, 'S&P': 0.1057679...
# 496  {'Ibex': 0.055356312899063675, 'S&P': 0.105604...
# 497  {'Ibex': 0.05567341265584475, 'S&P': 0.1054436...
# ...

# %% [markdown]
# ### Convierto la columna de pesos de cartera en varias columnas con las keys, tendre los datos mas ordenados, se veran de manera más clara y podré visualizarlos mejor.

# %%
FronEfi_separado = pd.json_normalize(FronEfi['Pesos Cartera'])


FronEfi = pd.concat([FronEfi.drop('Pesos Cartera', axis=1), FronEfi_separado], axis=1)

FronEfi
# Out:
#      Rendimiento  Volatilidad          Ibex           S&P            DJ  \
# 0       0.169501     0.439535  3.365445e-24  3.331164e-24  3.325071e-24
# 1       0.169501     0.439535  1.169997e-22  5.942709e-24  5.936540e-24
# 2       0.169501     0.439535  8.557770e-25  8.205995e-25  5.632550e-23
# 3       0.169501     0.439535  1.092506e-22  5.370386e-23 -1.813614e-24
# 4       0.169501     0.439535  1.118998e-22  5.635251e-23  5.634611e-23
# ..           ...          ...           ...           ...           ...
# 495     0.082448     0.114719  5.503479e-02  1.057680e-01  1.078422e-01
# 496     0.082298     0.114650  5.535631e-02  1.056047e-01  1.077340e-01
# 497     0.082149     0.114583  5.567341e-02  1.054437e-01  1.076272e-01
# 498     0.082002     0.114518  5.598615e-02  1.052848e-01  1.075219e-01
# 499     0.081858     0.114454  5.629459e-02  1.051282e-01  1.074181e-01
#
#       NASDAQ_COMP  NASDAQ_100          FTSE           CAC       EUSTOXX  \
# ...

# %% [markdown]
# ## Agrego 4 columnas para agrupar los índices por continentes

# %%
FronEfi["ASIA"] = FronEfi.apply(lambda row: sum(row[titulo] for titulo in ["NIKKEI", "NIFTY", "HANGSENG"]), axis=1)
FronEfi["EUROPE"] = FronEfi.apply(lambda row: sum(row[titulo] for titulo in ["Ibex", "FTSE", "CAC", "GDA", "EUSTOXX"]), axis=1)
FronEfi["NORTH AMERICA"] = FronEfi.apply(lambda row: sum(row[titulo] for titulo in ["S&P", "DJ"]), axis=1)
FronEfi["GLOBAL"] = FronEfi.apply(lambda row: sum(row[titulo] for titulo in ["NASDAQ_COMP", "NASDAQ_100"]), axis=1)

# %%
FronEfi
# Out:
#      Rendimiento  Volatilidad          Ibex           S&P            DJ  \
# 0       0.169501     0.439535  3.365445e-24  3.331164e-24  3.325071e-24
# 1       0.169501     0.439535  1.169997e-22  5.942709e-24  5.936540e-24
# 2       0.169501     0.439535  8.557770e-25  8.205995e-25  5.632550e-23
# 3       0.169501     0.439535  1.092506e-22  5.370386e-23 -1.813614e-24
# 4       0.169501     0.439535  1.118998e-22  5.635251e-23  5.634611e-23
# ..           ...          ...           ...           ...           ...
# 495     0.082448     0.114719  5.503479e-02  1.057680e-01  1.078422e-01
# 496     0.082298     0.114650  5.535631e-02  1.056047e-01  1.077340e-01
# 497     0.082149     0.114583  5.567341e-02  1.054437e-01  1.076272e-01
# 498     0.082002     0.114518  5.598615e-02  1.052848e-01  1.075219e-01
# 499     0.081858     0.114454  5.629459e-02  1.051282e-01  1.074181e-01
#
#       NASDAQ_COMP  NASDAQ_100          FTSE           CAC       EUSTOXX  \
# ...

# %% [markdown]
# # Perfecto ya tengo la frontera eficiente de las carteras que contienen los 12 índices, ya puedo descargarmela y trabajar con ella en PowerBi.

# %%
#FronEfi.to_excel("C:/Users/Lorenzo/Desktop/Proyecto Final MARKOVITZ/FrontEfi.xlsx", index=False)

# %% [markdown]
# ## Calculo las correlaciones para futuras mejoras del modelo

# %% [markdown]
# # Correlación

# %%
mergeo_indices = pd.concat([r_CAC, r_Ibex, r_DJ, r_EUROSTOXX50, r_FTSE, r_GDA, r_HANGSENG, r_NASDAQ100, r_NASDAQ_COMP, r_NIFTY50, r_NIKKEI225, r_SP500], axis=1)
mergeo_indices
# Out:
#                  CAC   Ibex_35  Dow_Jones  EURO_STOXX_50      FTSE       GDA  \
# Date
# 2013-06-10       NaN       NaN        NaN            NaN       NaN       NaN
# 2013-06-11       NaN       NaN        NaN            NaN       NaN       NaN
# 2013-06-12       NaN       NaN        NaN            NaN       NaN       NaN
# 2013-06-13       NaN       NaN        NaN            NaN       NaN       NaN
# 2013-06-14       NaN       NaN        NaN            NaN       NaN       NaN
# ...              ...       ...        ...            ...       ...       ...
# 2023-06-02  0.121103  0.054435   0.015474       0.135754  0.000947  0.111120
# 2023-06-05  0.099580  0.050613   0.020157       0.133101 -0.001012  0.124313
# 2023-06-06  0.109017  0.052936   0.019975       0.153250  0.012624  0.162087
# 2023-06-07  0.116949  0.074456   0.014614       0.192462  0.002116  0.188689
# 2023-06-08  0.136222  0.122804        NaN       0.227198  0.001819  0.202348
#
# ...

# %%
correlacion = mergeo_indices.corr()
correlacion
# Out:
#                        CAC   Ibex_35  Dow_Jones  EURO_STOXX_50      FTSE  \
# CAC               1.000000  0.877098   0.775449       0.954898  0.785899
# Ibex_35           0.877098  1.000000   0.681981       0.900011  0.779935
# Dow_Jones         0.775449  0.681981   1.000000       0.770364  0.682078
# EURO_STOXX_50     0.954898  0.900011   0.770364       1.000000  0.704431
# FTSE              0.785899  0.779935   0.682078       0.704431  1.000000
# GDA               0.881117  0.808757   0.794070       0.943608  0.648746
# HANG_SENG_Index   0.553301  0.599682   0.764569       0.625035  0.466605
# NASDAQ_100        0.481849  0.368449   0.752452       0.575476  0.185812
# NASDAQ_Composite  0.527567  0.408197   0.798013       0.612051  0.249345
# NIFTY_50          0.742662  0.768614   0.784716       0.765855  0.652591
# NIKKEI_225        0.719207  0.650493   0.710185       0.773743  0.422776
# S&P_500           0.736775  0.610758   0.931950       0.759591  0.543921
#
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(correlacion, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## ALTA CORRELACIÓN:
#
# ### (GLOBAL, USA) "TECH" NASDAQ 100  | 99% | NASDAQ COMPOSITE "COMBINED, HIGH TECH" (GLOBAL, USA)
# ### (EUROPA) "COMBINED" EURO STOXX 50 | 96% | CAC "COMBINED" (FRANCIA)
# ### (EUROPA) "COMBINED" EURO STOXX 50 | 94% | GDA "COMBINED" (ALEMANIA)
# ### (USA) "COMBINED" S&P 500 | 93% | DOW JONES "INDUSTRIAL" (USA)
# ### (USA) "COMBINED" S&P 500 | 91% | NASDAQ COMPOSITE "COMBINED, HIGH TECH" (GLOBAL, USA)
# ### (EUROPA) "COMBINED" EURO STOXX 50 | 90% | IBEX 35 "COMBINED" (ESPAÑA)

# %% [markdown]
# # DIBUJAMOS EL GRAFICO

# %%
df_transposed.plot.scatter(x = 'Volatilidad', y = 'Rentabilidad promedio');

# %% [markdown]
# ## COVARIANZA

# %%
rendi = mergeo_indices.dropna()

rendimientos = rendi.values

# Calcular la matriz de covarianza
covarianza = np.cov(rendimientos, rowvar=False)

print("Matriz de covarianza:")
print(covarianza)
# Out:
# Matriz de covarianza:
# [[0.02128315 0.02049948 0.01419311 0.02028048 0.01243833 0.0194908
#   0.01353444 0.01360232 0.01501099 0.01959134 0.01658157 0.01433257]
#  [0.02049948 0.0257216  0.0136567  0.02095136 0.01364374 0.01961653
#   0.01602231 0.01121696 0.01255769 0.02216435 0.01643329 0.01292265]
#  [0.01419311 0.0136567  0.01575964 0.01406926 0.009282   0.01509743
#   0.01605208 0.01821096 0.01947078 0.01782687 0.01395872 0.0155993 ]
#  [0.02028048 0.02095136 0.01406926 0.02116912 0.01115996 0.02082162
#   0.01521933 0.01626315 0.01741961 0.02009757 0.01779721 0.01476966]
#  [0.01243833 0.01364374 0.009282   0.01115996 0.01180843 0.01067102
#   0.008501   0.00373611 0.00513149 0.01286718 0.00724977 0.00780494]
#  [0.0194908  0.01961653 0.01509743 0.02082162 0.01067102 0.0229893
#   0.01801168 0.01998825 0.02118919 0.01948505 0.01986908 0.01597334]
#  [0.01353444 0.01602231 0.01605208 0.01521933 0.008501   0.01801168
# ...

# %%
std
# Out:
# [0.16042877342117778,
#  0.1339971775768312,
#  0.12585099030655061,
#  0.19473630436932618,
#  0.19319071447818106,
#  0.10841240530051825,
#  0.146088268638503,
#  0.14538243761992836,
#  0.15087438211565427,
#  0.15741066476206192,
#  0.17974363681849345,
#  0.16559348633308285]

# %%
df_std = pd.DataFrame(std, columns=['STD'])
df_std
# Out:
#          STD
# 0   0.160429
# 1   0.133997
# 2   0.125851
# 3   0.194736
# 4   0.193191
# 5   0.108412
# 6   0.146088
# 7   0.145382
# 8   0.150874
# 9   0.157411
# 10  0.179744
# 11  0.165593

# %%
indexes = ['CAC', 'Ibex_35', 'Dow_Jones', 'EURO_STOXX_50', 'FTSE', 'GDA', 'HANG_SENG_Index', 'NASDAQ_100', 'NASDAQ_Composite', 'NIFTY_50', 'NIKKEI_225', 'S&P_500']
df_std['Indice'] = indexes
df_std = df_std.set_index('Indice')
df_std
# Out:
#                        STD
# Indice
# CAC               0.160429
# Ibex_35           0.133997
# Dow_Jones         0.125851
# EURO_STOXX_50     0.194736
# FTSE              0.193191
# GDA               0.108412
# HANG_SENG_Index   0.146088
# NASDAQ_100        0.145382
# NASDAQ_Composite  0.150874
# NIFTY_50          0.157411
# NIKKEI_225        0.179744
# S&P_500           0.165593

# %%
covariance_df = correlacion * (df_std['STD'].values.reshape(-1, 1) * df_std['STD'].values)

covariance_df #Matriz de Varianzas y covarianzas (sin ponderar)
# Out:
#                        CAC   Ibex_35  Dow_Jones  EURO_STOXX_50      FTSE  \
# CAC               0.025737  0.018855   0.015656       0.029832  0.024358
# Ibex_35           0.018855  0.017955   0.011501       0.023485  0.020190
# Dow_Jones         0.015656  0.011501   0.015838       0.018880  0.016584
# EURO_STOXX_50     0.029832  0.023485   0.018880       0.037922  0.026502
# FTSE              0.024358  0.020190   0.016584       0.026502  0.037323
# GDA               0.015325  0.011749   0.010834       0.019921  0.013588
# HANG_SENG_Index   0.012968  0.011739   0.014057       0.017781  0.013169
# NASDAQ_100        0.011238  0.007178   0.013767       0.016292  0.005219
# NASDAQ_Composite  0.012770  0.008252   0.015152       0.017982  0.007268
# NIFTY_50          0.018755  0.016212   0.015545       0.023476  0.019845
# NIKKEI_225        0.020739  0.015667   0.016065       0.027083  0.014681
# S&P_500           0.019573  0.013552   0.019422       0.024495  0.017401
#
# ...
