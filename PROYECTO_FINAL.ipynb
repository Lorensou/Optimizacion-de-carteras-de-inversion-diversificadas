# %% [markdown]
# # PROYECTO CARTERAS DE INVERSIÓN

# %%
import pandas as pd
import numpy as np

# %%
# %pip install yfinance
import yfinance as yf
# Out:
# Requirement already satisfied: yfinance in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (0.2.18)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from yfinance) (37.0.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from yfinance) (1.24.2)
# Requirement already satisfied: requests>=2.26 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from yfinance) (2023.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from requests>=2.26->yfinance) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: pycparser in c:\users\lorenzo\anaconda3\anaconda\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # SPAIN

# %% [markdown]
# ### IBEX 35

# %%
Ibex = yf.download(tickers='^IBEX', period='10y', interval='1d')

Ibex['datetime']=Ibex.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Ibex.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-05  8308.400391  8430.000000  8283.299805  8290.700195  8290.691406
# 2013-06-06  8308.599609  8418.299805  8216.700195  8216.700195  8216.691406
# 2013-06-07  8229.200195  8308.700195  8165.100098  8266.599609  8266.590820
# 2013-06-10  8270.799805  8321.700195  8184.600098  8227.400391  8227.391602
# 2013-06-11  8179.600098  8182.500000  7980.100098  8089.299805  8089.291504
#
#                Volume   datetime
# Date
# 2013-06-05  261977400 2013-06-05
# 2013-06-06  278270200 2013-06-06
# 2013-06-07  297871400 2013-06-07
# 2013-06-10  276422600 2013-06-10
# 2013-06-11  392860200 2013-06-11

# %%
Ibex.shape
# Out:
# (2558, 7)

# %% [markdown]
# # USA

# %% [markdown]
# ### STANDARD & POOR'S 500

# %%
SP500 = yf.download(tickers='^GSPC', period='10y', interval='1d')

SP500['datetime']=SP500.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
SP500.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-05  1629.050049  1629.310059  1607.089966  1608.900024  1608.900024
# 2013-06-06  1609.290039  1622.560059  1598.229980  1622.560059  1622.560059
# 2013-06-07  1625.270020  1644.400024  1625.270020  1643.380005  1643.380005
# 2013-06-10  1644.670044  1648.689941  1639.260010  1642.810059  1642.810059
# 2013-06-11  1638.640015  1640.130005  1622.920044  1626.130005  1626.130005
#
#                 Volume   datetime
# Date
# 2013-06-05  3632350000 2013-06-05
# 2013-06-06  3547380000 2013-06-06
# 2013-06-07  3371990000 2013-06-07
# 2013-06-10  2978730000 2013-06-10
# 2013-06-11  3435710000 2013-06-11

# %%
SP500.shape
# Out:
# (2518, 7)

# %% [markdown]
# ### DOW JONES INDUSTRIAL AVERAGE

# %%
DJ = yf.download(tickers='^DJI', period='10y', interval='1d')

DJ['datetime']=DJ.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
DJ.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2013-06-05  15168.099609  15168.629883  14945.570312  14960.589844
# 2013-06-06  14955.450195  15040.620117  14844.219727  15040.620117
# 2013-06-07  15044.459961  15255.580078  15044.459961  15248.120117
# 2013-06-10  15247.809570  15300.639648  15211.250000  15238.589844
# 2013-06-11  15231.379883  15251.070312  15086.089844  15122.019531
#
#                Adj Close     Volume   datetime
# Date
# 2013-06-05  14960.589844  141400000 2013-06-05
# 2013-06-06  15040.620117  140410000 2013-06-06
# 2013-06-07  15248.120117  137380000 2013-06-07
# 2013-06-10  15238.589844   94250000 2013-06-10
# 2013-06-11  15122.019531  101610000 2013-06-11

# %%
DJ.shape
# Out:
# (2518, 7)

# %% [markdown]
# # GLOBAL

# %% [markdown]
# ### NASDAQ COMPOSITE

# %%
NASDAQ_COMP = yf.download(tickers='^IXIC', period='10y', interval='1d')

NASDAQ_COMP['datetime']=NASDAQ_COMP.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
NASDAQ_COMP.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-05  3432.850098  3446.149902  3397.909912  3401.479980  3401.479980
# 2013-06-06  3404.409912  3424.050049  3378.239990  3424.050049  3424.050049
# 2013-06-07  3437.840088  3471.729980  3429.429932  3469.219971  3469.219971
# 2013-06-10  3475.679932  3484.810059  3465.540039  3473.770020  3473.770020
# 2013-06-11  3436.620117  3466.570068  3426.570068  3436.949951  3436.949951
#
#                 Volume   datetime
# Date
# 2013-06-05  1813890000 2013-06-05
# 2013-06-06  1802700000 2013-06-06
# 2013-06-07  1646810000 2013-06-07
# 2013-06-10  1556520000 2013-06-10
# 2013-06-11  1560370000 2013-06-11

# %%
NASDAQ_COMP.shape
# Out:
# (2518, 7)

# %% [markdown]
# ### NASDAQ 100 (TECH)

# %%
NASDAQ100 = yf.download(tickers='^NDX', period='10y', interval='1d')

NASDAQ100['datetime']=NASDAQ100.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
NASDAQ100.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-05  2961.669922  2975.830078  2933.219971  2937.139893  2937.139893
# 2013-06-06  2940.870117  2950.300049  2911.939941  2950.300049  2950.300049
# 2013-06-07  2960.899902  2993.129883  2955.100098  2990.870117  2990.870117
# 2013-06-10  2995.030029  3004.669922  2985.500000  2990.489990  2990.489990
# 2013-06-11  2959.439941  2987.850098  2952.070068  2959.840088  2959.840088
#
#                 Volume   datetime
# Date
# 2013-06-05  1813890000 2013-06-05
# 2013-06-06  1802700000 2013-06-06
# 2013-06-07  1646810000 2013-06-07
# 2013-06-10  1556520000 2013-06-10
# 2013-06-11  1560370000 2013-06-11

# %%
NASDAQ100.shape
# Out:
# (2518, 7)

# %% [markdown]
# # UK

# %% [markdown]
# ### FTSE

# %%
FTSE = yf.download(tickers='^FTSE', period='10y', interval='1d')

FTSE['datetime']=FTSE.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
FTSE.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-05  6558.600098  6558.600098  6419.299805  6419.299805  6419.299805
# 2013-06-06  6419.299805  6435.399902  6336.100098  6336.100098  6336.100098
# 2013-06-07  6336.100098  6421.399902  6313.600098  6412.000000  6412.000000
# 2013-06-10  6412.000000  6421.200195  6379.600098  6400.500000  6400.500000
# 2013-06-11  6400.500000  6401.200195  6280.100098  6340.100098  6340.100098
#
#                Volume   datetime
# Date
# 2013-06-05  800986600 2013-06-05
# 2013-06-06  680974000 2013-06-06
# 2013-06-07  786639400 2013-06-07
# 2013-06-10  597227000 2013-06-10
# 2013-06-11  736368300 2013-06-11

# %%
FTSE.shape
# Out:
# (2525, 7)

# %% [markdown]
# # FRANCE

# %% [markdown]
# ### CAC

# %%
CAC = yf.download(tickers='^FCHI', period='10y', interval='1d')

CAC['datetime']=CAC.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
CAC.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-05  3903.590088  3915.709961  3852.439941  3852.439941  3852.439941
# 2013-06-06  3861.239990  3877.959961  3814.280029  3814.280029  3814.280029
# 2013-06-07  3821.070068  3889.550049  3800.850098  3872.590088  3872.590088
# 2013-06-10  3864.080078  3884.639893  3853.879883  3864.360107  3864.360107
# 2013-06-11  3847.000000  3849.360107  3780.389893  3810.560059  3810.560059
#
#                Volume   datetime
# Date
# 2013-06-05   98550400 2013-06-05
# 2013-06-06   92674800 2013-06-06
# 2013-06-07  102233400 2013-06-07
# 2013-06-10   67885400 2013-06-10
# 2013-06-11  106952600 2013-06-11

# %%
CAC.shape
# Out:
# (2560, 7)

# %% [markdown]
# # EUROPE

# %% [markdown]
# ### EUROSTOXX 50

# %%
EUROSTOXX50 = yf.download(tickers='^STOXX50E', period='10y', interval='1d')

EUROSTOXX50['datetime']=EUROSTOXX50.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
EUROSTOXX50.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-05  2741.560059  2753.290039  2709.330078  2709.330078  2709.330078
# 2013-06-06  2709.500000  2729.409912  2676.209961  2676.209961  2676.209961
# 2013-06-07  2680.820068  2733.959961  2664.070068  2724.080078  2724.080078
# 2013-06-10  2719.179932  2734.290039  2708.719971  2719.399902  2719.399902
# 2013-06-11  2707.129883  2707.129883  2656.000000  2683.199951  2683.199951
#
#             Volume   datetime
# Date
# 2013-06-05       0 2013-06-05
# 2013-06-06       0 2013-06-06
# 2013-06-07       0 2013-06-07
# 2013-06-10       0 2013-06-10
# 2013-06-11       0 2013-06-11

# %%
EUROSTOXX50.shape
# Out:
# (2509, 7)

# %% [markdown]
# # GERMANY

# %% [markdown]
# ### GDA

# %%
GDA = yf.download(tickers='^GDAXI', period='10y', interval='1d')

GDA['datetime']=GDA.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
GDA.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-05  8229.230469  8293.280273  8182.080078  8196.179688  8196.179688
# 2013-06-06  8188.819824  8235.089844  8098.810059  8098.810059  8098.810059
# 2013-06-07  8124.879883  8279.030273  8034.549805  8254.679688  8254.679688
# 2013-06-10  8246.040039  8355.790039  8245.940430  8307.690430  8307.690430
# 2013-06-11  8256.190430  8260.860352  8141.020020  8222.459961  8222.459961
#
#                Volume   datetime
# Date
# 2013-06-05   89163200 2013-06-05
# 2013-06-06   85243600 2013-06-06
# 2013-06-07  103601100 2013-06-07
# 2013-06-10   75733100 2013-06-10
# 2013-06-11   96689800 2013-06-11

# %%
GDA.shape
# Out:
# (2533, 7)

# %% [markdown]
# # JAPAN

# %% [markdown]
# ### NIKKEI 225

# %%
NIKKEI225 = yf.download(tickers='^N225', period='10y', interval='1d')

NIKKEI225['datetime']=NIKKEI225.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
NIKKEI225.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2013-06-05  13566.750000  13711.419922  13011.160156  13014.870117
# 2013-06-06  12925.290039  13238.530273  12862.019531  12904.019531
# 2013-06-07  12706.410156  13106.200195  12548.200195  12877.530273
# 2013-06-10  13141.849609  13514.200195  13141.370117  13514.200195
# 2013-06-11  13504.769531  13584.309570  13296.309570  13317.620117
#
#                Adj Close     Volume   datetime
# Date
# 2013-06-05  13014.870117  303700000 2013-06-05
# 2013-06-06  12904.019531  314000000 2013-06-06
# 2013-06-07  12877.530273  324500000 2013-06-07
# 2013-06-10  13514.200195  241400000 2013-06-10
# 2013-06-11  13317.620117  260200000 2013-06-11

# %%
NIKKEI225.shape
# Out:
# (2444, 7)

# %% [markdown]
# # INDIA

# %% [markdown]
# ### NIFTY 50

# %%
NIFTY50 = yf.download(tickers='^NSEI', period='10y', interval='1d')

NIFTY50['datetime']=NIFTY50.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
NIFTY50.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-06-05  5908.299805  5935.200195  5883.700195  5923.850098  5923.850098
# 2013-06-06  5895.000000  5956.549805  5869.500000  5921.399902  5921.399902
# 2013-06-07  5900.049805  5972.700195  5871.299805  5881.000000  5881.000000
# 2013-06-10  5907.899902  5931.649902  5857.399902  5878.000000  5878.000000
# 2013-06-11  5848.750000  5868.049805  5780.350098  5788.799805  5788.799805
#
#             Volume   datetime
# Date
# 2013-06-05  110200 2013-06-05
# 2013-06-06  114200 2013-06-06
# 2013-06-07  118300 2013-06-07
# 2013-06-10  100100 2013-06-10
# 2013-06-11  180900 2013-06-11

# %%
NIFTY50.shape
# Out:
# (2454, 7)

# %% [markdown]
# # HONG KONG

# %% [markdown]
# ### HANG SENG INDEX

# %%
HANGSENG = yf.download(tickers='^HSI', period='10y', interval='1d')

HANGSENG['datetime']=HANGSENG.index
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
HANGSENG.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2013-06-05  22141.669922  22174.689453  21933.919922  22069.240234
# 2013-06-06  21908.449219  21949.810547  21799.250000  21838.429688
# 2013-06-07  21768.240234  21820.429688  21506.330078  21575.259766
# 2013-06-10  21592.900391  21723.859375  21497.550781  21615.089844
# 2013-06-11  21542.300781  21632.009766  21307.990234  21354.660156
#
#                Adj Close      Volume   datetime
# Date
# 2013-06-05  22069.240234  1516765700 2013-06-05
# 2013-06-06  21838.429688  1711966400 2013-06-06
# 2013-06-07  21575.259766  1834956400 2013-06-07
# 2013-06-10  21615.089844  1464580800 2013-06-10
# 2013-06-11  21354.660156  2121919200 2013-06-11

# %%
HANGSENG.shape
# Out:
# (2462, 7)

# %% [markdown]
# # ESTANDARIZAR FECHAS

# %%
print(Ibex.shape)
print(SP500.shape)
print(DJ.shape)
print(NASDAQ_COMP.shape)
print(NASDAQ100.shape)
print(FTSE.shape)
print(CAC.shape)
print(EUROSTOXX50.shape)
print(GDA.shape)
print(NIKKEI225.shape)
print(NIFTY50.shape)
print(HANGSENG.shape)
# Out:
# (2558, 7)
# (2518, 7)
# (2518, 7)
# (2518, 7)
# (2518, 7)
# (2525, 7)
# (2560, 7)
# (2509, 7)
# (2533, 7)
# (2444, 7)
# (2454, 7)
# (2462, 7)

# %%
print('Ibex first' , Ibex.index[0])
print('Ibex last' , Ibex.index[-1])
print('SP500 first' , SP500.index[0])
print('SP500 last' , SP500.index[-1])
print('Dow Jones first' , DJ.index[0])
print('Dow Jones last' , DJ.index[-1])
print('NASDAQ_COMP first' , NASDAQ_COMP.index[0])
print('NASDAQ_COMP last' , NASDAQ_COMP.index[-1])
print('NASDAQ100 first' , NASDAQ100.index[0])
print('NASDAQ100 last' , NASDAQ100.index[-1])
print('FTSE first' , FTSE.index[0])
print('FTSE last' , FTSE.index[-1])
print('CAC first' , CAC.index[0])
print('CAC last' , CAC.index[-1])
print('EUROSTOXX50 first' , EUROSTOXX50.index[0])
print('EUROSTOXX50 last' , EUROSTOXX50.index[-1])
print('GDA first' , GDA.index[0])
print('GDA last' , GDA.index[-1])
print('NIKKEI225 first' , NIKKEI225.index[0])
print('NIKKEI225 last' , NIKKEI225.index[-1])
print('NIFTY50 first' , NIFTY50.index[0])
print('NIFTY50 last' , NIFTY50.index[-1])
print('HANGSENG first' , HANGSENG.index[0])
print('HANGSENG last' , HANGSENG.index[-1])
# Out:
# Ibex first 2013-06-05 00:00:00
# Ibex last 2023-06-05 00:00:00
# SP500 first 2013-06-05 00:00:00
# SP500 last 2023-06-05 00:00:00
# Dow Jones first 2013-06-05 00:00:00
# Dow Jones last 2023-06-05 00:00:00
# NASDAQ_COMP first 2013-06-05 00:00:00
# NASDAQ_COMP last 2023-06-05 00:00:00
# NASDAQ100 first 2013-06-05 00:00:00
# NASDAQ100 last 2023-06-05 00:00:00
# FTSE first 2013-06-05 00:00:00
# FTSE last 2023-06-05 00:00:00
# CAC first 2013-06-05 00:00:00
# CAC last 2023-06-05 00:00:00
# EUROSTOXX50 first 2013-06-05 00:00:00
# EUROSTOXX50 last 2023-06-05 00:00:00
# GDA first 2013-06-05 00:00:00
# GDA last 2023-06-05 00:00:00
# NIKKEI225 first 2013-06-05 00:00:00
# NIKKEI225 last 2023-06-05 00:00:00
# NIFTY50 first 2013-06-05 00:00:00
# NIFTY50 last 2023-06-05 00:00:00
# HANGSENG first 2013-06-05 00:00:00
# HANGSENG last 2023-06-05 00:00:00

# %%
# Para empezar vamos a quedarnos con las columnas de indice(fecha) y de ajuste cierre del dia de cada uno de los indices porque son los datos que realmente nos interesan.

# Nos quedamos con el valor de ajuste de cierre ya que es un indicador más coherente.

# Ahora debemos cambiar el nombre de columna del ajuste de cierre por el nombre del indice. Esto era para el merge que al final voy a deshacer, ya que esta lo dejo...

# %%
import matplotlib.pyplot as plt

# %%
Ibex  = Ibex.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
Ibex = Ibex.rename(columns={'Adj Close': 'Ibex_35'})
Ibex.head()
# Out:
#                 Ibex_35
# Date
# 2013-06-05  8290.691406
# 2013-06-06  8216.691406
# 2013-06-07  8266.590820
# 2013-06-10  8227.391602
# 2013-06-11  8089.291504

# %%
Ibex.plot(y='Ibex_35');

# %%
SP500  = SP500.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
SP500 = SP500.rename(columns={'Adj Close': 'S&P_500'})
SP500.head()
# Out:
#                 S&P_500
# Date
# 2013-06-05  1608.900024
# 2013-06-06  1622.560059
# 2013-06-07  1643.380005
# 2013-06-10  1642.810059
# 2013-06-11  1626.130005

# %%
SP500.plot(y='S&P_500');

# %%
DJ  = DJ.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
DJ = DJ.rename(columns={'Adj Close': 'Dow_Jones'})
DJ.head()
# Out:
#                Dow_Jones
# Date
# 2013-06-05  14960.589844
# 2013-06-06  15040.620117
# 2013-06-07  15248.120117
# 2013-06-10  15238.589844
# 2013-06-11  15122.019531

# %%
DJ.plot(y='Dow_Jones');

# %%
NASDAQ_COMP  = NASDAQ_COMP.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
NASDAQ_COMP = NASDAQ_COMP.rename(columns={'Adj Close': 'NASDAQ_Composite'})
NASDAQ_COMP.head()
# Out:
#             NASDAQ_Composite
# Date
# 2013-06-05       3401.479980
# 2013-06-06       3424.050049
# 2013-06-07       3469.219971
# 2013-06-10       3473.770020
# 2013-06-11       3436.949951

# %%
NASDAQ_COMP.plot(y='NASDAQ_Composite');

# %%
NASDAQ100  = NASDAQ100.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
NASDAQ100 = NASDAQ100.rename(columns={'Adj Close': 'NASDAQ_100'})
NASDAQ100.head()
# Out:
#              NASDAQ_100
# Date
# 2013-06-05  2937.139893
# 2013-06-06  2950.300049
# 2013-06-07  2990.870117
# 2013-06-10  2990.489990
# 2013-06-11  2959.840088

# %%
NASDAQ100.plot(y='NASDAQ_100');

# %%
FTSE  = FTSE.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
FTSE = FTSE.rename(columns={'Adj Close': 'FTSE'})
FTSE.head()
# Out:
#                    FTSE
# Date
# 2013-06-05  6419.299805
# 2013-06-06  6336.100098
# 2013-06-07  6412.000000
# 2013-06-10  6400.500000
# 2013-06-11  6340.100098

# %%
FTSE.plot(y='FTSE');

# %%
CAC  = CAC.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
CAC = CAC.rename(columns={'Adj Close': 'CAC'})
CAC.head()
# Out:
#                     CAC
# Date
# 2013-06-05  3852.439941
# 2013-06-06  3814.280029
# 2013-06-07  3872.590088
# 2013-06-10  3864.360107
# 2013-06-11  3810.560059

# %%
CAC.plot(y = 'CAC');

# %%
EUROSTOXX50  = EUROSTOXX50.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
EUROSTOXX50 = EUROSTOXX50.rename(columns={'Adj Close': 'EURO_STOXX_50'})
EUROSTOXX50.head()
# Out:
#             EURO_STOXX_50
# Date
# 2013-06-05    2709.330078
# 2013-06-06    2676.209961
# 2013-06-07    2724.080078
# 2013-06-10    2719.399902
# 2013-06-11    2683.199951

# %%
EUROSTOXX50.plot(y= 'EURO_STOXX_50');

# %%
GDA  = GDA.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
GDA = GDA.rename(columns={'Adj Close': 'GDA'})
GDA.head()
# Out:
#                     GDA
# Date
# 2013-06-05  8196.179688
# 2013-06-06  8098.810059
# 2013-06-07  8254.679688
# 2013-06-10  8307.690430
# 2013-06-11  8222.459961

# %%
GDA.plot( y = 'GDA');

# %%
NIKKEI225  = NIKKEI225.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
NIKKEI225 = NIKKEI225.rename(columns={'Adj Close': 'NIKKEI_225'})
NIKKEI225.head()
# Out:
#               NIKKEI_225
# Date
# 2013-06-05  13014.870117
# 2013-06-06  12904.019531
# 2013-06-07  12877.530273
# 2013-06-10  13514.200195
# 2013-06-11  13317.620117

# %%
NIKKEI225.plot(y = 'NIKKEI_225');

# %%
NIFTY50  = NIFTY50.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
NIFTY50 = NIFTY50.rename(columns={'Adj Close': 'NIFTY_50'})
NIFTY50.head()
# Out:
#                NIFTY_50
# Date
# 2013-06-05  5923.850098
# 2013-06-06  5921.399902
# 2013-06-07  5881.000000
# 2013-06-10  5878.000000
# 2013-06-11  5788.799805

# %%
NIFTY50.plot( y = 'NIFTY_50');

# %%
HANGSENG  = HANGSENG.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'datetime'], axis = 1)

# %%
HANGSENG = HANGSENG.rename(columns={'Adj Close': 'HANG_SENG_Index'})
HANGSENG.head()
# Out:
#             HANG_SENG_Index
# Date
# 2013-06-05     22069.240234
# 2013-06-06     21838.429688
# 2013-06-07     21575.259766
# 2013-06-10     21615.089844
# 2013-06-11     21354.660156

# %%
HANGSENG.plot( y = 'HANG_SENG_Index');

# %%
indices = [Ibex, SP500, DJ, NASDAQ_COMP, NASDAQ100, FTSE, CAC, EUROSTOXX50, GDA, NIKKEI225, NIFTY50, HANGSENG]

# %%
df = Ibex

# %%
for i in indices[1:]:
    df = df.join(i, how='inner')

print(df)
# Out:
#                 Ibex_35      S&P_500     Dow_Jones  NASDAQ_Composite  \
# Date
# 2013-06-05  8290.691406  1608.900024  14960.589844       3401.479980
# 2013-06-06  8216.691406  1622.560059  15040.620117       3424.050049
# 2013-06-07  8266.590820  1643.380005  15248.120117       3469.219971
# 2013-06-10  8227.391602  1642.810059  15238.589844       3473.770020
# 2013-06-11  8089.291504  1626.130005  15122.019531       3436.949951
# ...                 ...          ...           ...               ...
# 2023-05-30  9167.500000  4205.520020  33042.781250      13017.429688
# 2023-05-31  9050.200195  4179.830078  32908.269531      12935.290039
# 2023-06-01  9167.500000  4221.020020  33061.570312      13100.980469
# 2023-06-02  9317.299805  4282.370117  33762.761719      13240.769531
# 2023-06-05  9289.099609  4283.430176  33633.359375      13269.263672
#
#               NASDAQ_100         FTSE          CAC  EURO_STOXX_50  \
# Date
# 2013-06-05   2937.139893  6419.299805  3852.439941    2709.330078
# 2013-06-06   2950.300049  6336.100098  3814.280029    2676.209961
# 2013-06-07   2990.870117  6412.000000  3872.590088    2724.080078
# 2013-06-10   2990.489990  6400.500000  3864.360107    2719.399902
# 2013-06-11   2959.840088  6340.100098  3810.560059    2683.199951
# ...                  ...          ...          ...            ...
# 2023-05-30  14354.990234  7522.100098  7209.750000    4291.580078
# 2023-05-31  14254.089844  7446.100098  7098.700195    4218.040039
# 2023-06-01  14441.509766  7490.299805  7137.430176    4257.609863
# 2023-06-02  14546.639648  7607.299805  7270.689941    4323.520020
# 2023-06-05  14592.040039  7599.990234  7200.910156    4293.240234
#
#                      GDA    NIKKEI_225      NIFTY_50  HANG_SENG_Index
# Date
# 2013-06-05   8196.179688  13014.870117   5923.850098     22069.240234
# 2013-06-06   8098.810059  12904.019531   5921.399902     21838.429688
# 2013-06-07   8254.679688  12877.530273   5881.000000     21575.259766
# 2013-06-10   8307.690430  13514.200195   5878.000000     21615.089844
# 2013-06-11   8222.459961  13317.620117   5788.799805     21354.660156
# ...                  ...           ...           ...              ...
# 2023-05-30  15908.910156  31328.160156  18633.849609     18595.779297
# 2023-05-31  15664.019531  30887.880859  18534.400391     18234.269531
# 2023-06-01  15853.660156  31148.009766  18487.750000     18216.910156
# 2023-06-02  16051.230469  31524.220703  18534.099609     18949.939453
# 2023-06-05  15963.889648  32217.429688  18593.849609     19108.500000
#
# [2087 rows x 12 columns]

# %%
df.head()
# Out:
#                 Ibex_35      S&P_500     Dow_Jones  NASDAQ_Composite  \
# Date
# 2013-06-05  8290.691406  1608.900024  14960.589844       3401.479980
# 2013-06-06  8216.691406  1622.560059  15040.620117       3424.050049
# 2013-06-07  8266.590820  1643.380005  15248.120117       3469.219971
# 2013-06-10  8227.391602  1642.810059  15238.589844       3473.770020
# 2013-06-11  8089.291504  1626.130005  15122.019531       3436.949951
#
#              NASDAQ_100         FTSE          CAC  EURO_STOXX_50          GDA  \
# Date
# 2013-06-05  2937.139893  6419.299805  3852.439941    2709.330078  8196.179688
# 2013-06-06  2950.300049  6336.100098  3814.280029    2676.209961  8098.810059
# 2013-06-07  2990.870117  6412.000000  3872.590088    2724.080078  8254.679688
# 2013-06-10  2990.489990  6400.500000  3864.360107    2719.399902  8307.690430
# 2013-06-11  2959.840088  6340.100098  3810.560059    2683.199951  8222.459961
#
#               NIKKEI_225     NIFTY_50  HANG_SENG_Index
# Date
# 2013-06-05  13014.870117  5923.850098     22069.240234
# 2013-06-06  12904.019531  5921.399902     21838.429688
# 2013-06-07  12877.530273  5881.000000     21575.259766
# 2013-06-10  13514.200195  5878.000000     21615.089844
# 2013-06-11  13317.620117  5788.799805     21354.660156

# %%
df.shape
# Out:
# (2087, 12)

# %%
# GRAFICO APROXIMADO, FALTAN DIAS

# %%
df.plot( y=['Ibex_35', 'S&P_500', 'Dow_Jones', 'NASDAQ_Composite', 'NASDAQ_100', 'FTSE', 'CAC', 'EURO_STOXX_50', 'GDA', 'NIKKEI_225', 'NIFTY_50', 'HANG_SENG_Index'], kind='line', figsize = (25, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## invertir indice para tener los valores actuales primero

# %%
df = df.sort_index(ascending = False)
df.head()
# Out:
#                 Ibex_35      S&P_500     Dow_Jones  NASDAQ_Composite  \
# Date
# 2023-06-05  9289.099609  4283.430176  33633.359375      13269.263672
# 2023-06-02  9317.299805  4282.370117  33762.761719      13240.769531
# 2023-06-01  9167.500000  4221.020020  33061.570312      13100.980469
# 2023-05-31  9050.200195  4179.830078  32908.269531      12935.290039
# 2023-05-30  9167.500000  4205.520020  33042.781250      13017.429688
#
#               NASDAQ_100         FTSE          CAC  EURO_STOXX_50  \
# Date
# 2023-06-05  14592.040039  7599.990234  7200.910156    4293.240234
# 2023-06-02  14546.639648  7607.299805  7270.689941    4323.520020
# 2023-06-01  14441.509766  7490.299805  7137.430176    4257.609863
# 2023-05-31  14254.089844  7446.100098  7098.700195    4218.040039
# 2023-05-30  14354.990234  7522.100098  7209.750000    4291.580078
#
#                      GDA    NIKKEI_225      NIFTY_50  HANG_SENG_Index
# Date
# 2023-06-05  15963.889648  32217.429688  18593.849609     19108.500000
# 2023-06-02  16051.230469  31524.220703  18534.099609     18949.939453
# 2023-06-01  15853.660156  31148.009766  18487.750000     18216.910156
# 2023-05-31  15664.019531  30887.880859  18534.400391     18234.269531
# 2023-05-30  15908.910156  31328.160156  18633.849609     18595.779297

# %% [markdown]
# # RENTABILIDAD

# %%
#df.head()

# %%
#df.shape
#d_por_año = 2086/10
#d_por_año

# %%
#comprb = df.pct_change(periods=-208)
#comprb.head()

# %%
#df[208:]

# %%
#comprb.info()

# %%
#nulos = 2086 - 1878
#nulos

# %% [markdown]
# ### El merge no ha sido buena idea... voy a calcular las rentabilidades por separado y luego ver si hago merge

# %%
print('ibex', Ibex.shape)
print('sp', SP500.shape)
print('dj', DJ.shape)
print('nasdaq_comp', NASDAQ_COMP.shape)
print('nasdaq100', NASDAQ100.shape)
print('ftse', FTSE.shape)
print('cac', CAC.shape)
print('eurostox', EUROSTOXX50.shape)
print('gda', GDA.shape)
print('nikkey', NIKKEI225.shape)
print('nifty', NIFTY50.shape)
print('hangseng', HANGSENG.shape)
# Out:
# ibex (2558, 1)
# sp (2518, 1)
# dj (2518, 1)
# nasdaq_comp (2518, 1)
# nasdaq100 (2518, 1)
# ftse (2525, 1)
# cac (2560, 1)
# eurostox (2509, 1)
# gda (2533, 1)
# nikkey (2444, 1)
# nifty (2454, 1)
# hangseng (2462, 1)

# %% [markdown]
# ### Calculamos la rentabilidad anual diariamente. Posteriormente hacemos el promedio.

# %%
d_por_año = 2558/10
d_por_año              #para luego aplicar al peridodo de la función .pct_change y nos compare bien los precios con los de año anterior, este número tambien representa los días/año que ha estado abierta la bolsa en la que opera el índice.
# Out:
# 255.8

# %%
r_Ibex = Ibex['Ibex_35'].pct_change(periods= 255) 

rent_Ibex = r_Ibex.mean()

print(rent_Ibex)
r_Ibex
# Out:
# 0.0008168793089826123
# Date
# 2013-06-05         NaN
# 2013-06-06         NaN
# 2013-06-07         NaN
# 2013-06-10         NaN
# 2013-06-11         NaN
#                 ...
# 2023-05-30    0.048050
# 2023-05-31    0.035007
# 2023-06-01    0.050740
# 2023-06-02    0.054435
# 2023-06-05    0.050613
# Name: Ibex_35, Length: 2558, dtype: float64

# %%
ibex_log = np.log(Ibex).diff(255)
ibex_log
# Out:
#              Ibex_35
# Date
# 2013-06-05       NaN
# 2013-06-06       NaN
# 2013-06-07       NaN
# 2013-06-10       NaN
# 2013-06-11       NaN
# ...              ...
# 2023-05-30  0.046931
# 2023-05-31  0.034408
# 2023-06-01  0.049495
# 2023-06-02  0.053005
# 2023-06-05  0.049374
#
# [2558 rows x 1 columns]

# %%
r_Ibex.info() #Perfecto, solo tenemos el 2013 de nulos ya que no puede compararlo con el año anterior.
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 2558 entries, 2013-06-05 to 2023-06-05
# Series name: Ibex_35
# Non-Null Count  Dtype
# --------------  -----
# 2303 non-null   float64
# dtypes: float64(1)
# memory usage: 104.5 KB

# %%
r_SP500 = SP500['S&P_500'].pct_change(periods= 251) 

rent_SP500 = r_SP500.mean()

rent_SP500
# Out:
# 0.10178312959330114

# %%
r_DJ = DJ['Dow_Jones'].pct_change(periods= 251) 

rent_DJ = r_DJ.mean()

rent_DJ
# Out:
# 0.09033479128964703

# %%
r_NASDAQ_COMP = NASDAQ_COMP['NASDAQ_Composite'].pct_change(periods= 251) 

rent_NASDAQ_COMP = r_NASDAQ_COMP.mean()

rent_NASDAQ_COMP
# Out:
# 0.14430960248431568

# %%
r_NASDAQ100 = NASDAQ100['NASDAQ_100'].pct_change(periods= 251) 

rent_NASDAQ100 = r_NASDAQ100.mean()

rent_NASDAQ100
# Out:
# 0.1696668418765673

# %%
r_FTSE = FTSE['FTSE'].pct_change(periods= 252) 

rent_FTSE = r_FTSE.mean()

rent_FTSE
# Out:
# 0.01967902593893754

# %%
r_CAC = CAC['CAC'].pct_change(periods= 256) 

rent_CAC = r_CAC.mean()

rent_CAC
# Out:
# 0.06234519717358708

# %%
r_EUROSTOXX50 = EUROSTOXX50['EURO_STOXX_50'].pct_change(periods= 250) 

rent_EUROSTOXX50 = r_EUROSTOXX50.mean()

rent_EUROSTOXX50
# Out:
# 0.03967441474209366

# %%
r_GDA = GDA['GDA'].pct_change(periods= 253) 

rent_GDA = r_GDA.mean()

rent_GDA
# Out:
# 0.06263057886353307

# %%
r_NIKKEI225 = NIKKEI225['NIKKEI_225'].pct_change(periods= 244) 

rent_NIKKEI225 = r_NIKKEI225.mean()

rent_NIKKEI225
# Out:
# 0.08565143315156529

# %%
r_NIFTY50 = NIFTY50['NIFTY_50'].pct_change(periods= 245) 

rent_NIFTY50 = r_NIFTY50.mean()

rent_NIFTY50
# Out:
# 0.1363221181416457

# %%
r_HANGSENG = HANGSENG['HANG_SENG_Index'].pct_change(periods= 246) 

rent_HANGSENG = r_HANGSENG.mean()

rent_HANGSENG
# Out:
# -0.0013209553349392326

# %%
column_names = ['Ibex', 'S&P', 'DJ', 'NASDAQ_COMP', 'NASDAQ_100', 'FTSE', 'CAC', 'EUSTOXX', 'GDA', 'NIKKEI', 'NIFTY', 'HANGSENG']
values = [rent_Ibex, rent_SP500, rent_DJ, rent_NASDAQ_COMP, rent_NASDAQ100, rent_FTSE, rent_CAC, rent_EUROSTOXX50, rent_GDA, rent_NIKKEI225, rent_NIFTY50, rent_HANGSENG]

ROI_STD = pd.DataFrame(columns=column_names, data=[values])
ROI_STD
# Out:
#        Ibex       S&P        DJ  NASDAQ_COMP  NASDAQ_100      FTSE       CAC  \
# 0  0.000817  0.101783  0.090335      0.14431    0.169667  0.019679  0.062345
#
#     EUSTOXX       GDA    NIKKEI     NIFTY  HANGSENG
# 0  0.039674  0.062631  0.085651  0.136322 -0.001321

# %% [markdown]
# ## Riesgo

# %% [markdown]
# #### Calculo la desviación estándar de las rentabilidades anuales diarias de cada índice.

# %%
std_Ibex = r_Ibex.std()
std_Ibex
# Out:
# 0.16085578056214825

# %%
std_SP500 = r_SP500.std()
std_SP500
# Out:
# 0.13399299198533746

# %%
std_DJ = r_DJ.std()
std_DJ
# Out:
# 0.12580757068056478

# %%
std_NASDAQ_COMP = r_NASDAQ_COMP.std()
std_NASDAQ_COMP
# Out:
# 0.19472382429141202

# %%
std_NASDAQ100 = r_NASDAQ100.std()
std_NASDAQ100
# Out:
# 0.19318334272148377

# %%
std_FTSE = r_FTSE.std()
std_FTSE
# Out:
# 0.10842607985125395

# %%
std_CAC = r_CAC.std()
std_CAC
# Out:
# 0.14614878794373087

# %%
std_EUROSTOXX50 = r_EUROSTOXX50.std()
std_EUROSTOXX50
# Out:
# 0.14542148121066262

# %%
std_GDA = r_GDA.std()
std_GDA
# Out:
# 0.1509211832874728

# %%
std_NIKKEI225 = r_NIKKEI225.std()
std_NIKKEI225
# Out:
# 0.1574257033175363

# %%
std_NIFTY50 = r_NIFTY50.std()
std_NIFTY50
# Out:
# 0.17983163340458547

# %%
std_HANGSENG = r_HANGSENG.std()
std_HANGSENG
# Out:
# 0.16555362089696174

# %%
std = [std_Ibex, std_SP500, std_DJ, std_NASDAQ_COMP, std_NASDAQ100, std_FTSE, std_CAC, std_EUROSTOXX50, std_GDA, std_NIKKEI225, std_NIFTY50, std_HANGSENG]

# %%
ROI_STD = pd.DataFrame(columns=column_names, data=[values, std])
ROI_STD
# Out:
#        Ibex       S&P        DJ  NASDAQ_COMP  NASDAQ_100      FTSE       CAC  \
# 0  0.000817  0.101783  0.090335     0.144310    0.169667  0.019679  0.062345
# 1  0.160856  0.133993  0.125808     0.194724    0.193183  0.108426  0.146149
#
#     EUSTOXX       GDA    NIKKEI     NIFTY  HANGSENG
# 0  0.039674  0.062631  0.085651  0.136322 -0.001321
# 1  0.145421  0.150921  0.157426  0.179832  0.165554

# %%
df_transposed = ROI_STD.transpose()
df_transposed
# Out:
#                     0         1
# Ibex         0.000817  0.160856
# S&P          0.101783  0.133993
# DJ           0.090335  0.125808
# NASDAQ_COMP  0.144310  0.194724
# NASDAQ_100   0.169667  0.193183
# FTSE         0.019679  0.108426
# CAC          0.062345  0.146149
# EUSTOXX      0.039674  0.145421
# GDA          0.062631  0.150921
# NIKKEI       0.085651  0.157426
# NIFTY        0.136322  0.179832
# HANGSENG    -0.001321  0.165554

# %%
df_transposed = df_transposed.rename(columns={0: 'Rentabilidad promedio', 1: 'Volatilidad'})
df_transposed
# Out:
#              Rentabilidad promedio  Volatilidad
# Ibex                      0.000817     0.160856
# S&P                       0.101783     0.133993
# DJ                        0.090335     0.125808
# NASDAQ_COMP               0.144310     0.194724
# NASDAQ_100                0.169667     0.193183
# FTSE                      0.019679     0.108426
# CAC                       0.062345     0.146149
# EUSTOXX                   0.039674     0.145421
# GDA                       0.062631     0.150921
# NIKKEI                    0.085651     0.157426
# NIFTY                     0.136322     0.179832
# HANGSENG                 -0.001321     0.165554

# %%
from  Mis_funciones import *

# %%
FronEfi = frontera_eficiente(df_transposed['Rentabilidad promedio'], df_transposed['Volatilidad'])
FronEfi
# Out:
#     Rendimiento  Volatilidad  \
# 0      0.169667     0.439526
# 1      0.169667     0.439526
# 2      0.169667     0.439526
# 3      0.169667     0.439526
# 4      0.169667     0.439526
# ..          ...          ...
# 95     0.085338     0.116149
# 96     0.084414     0.115640
# 97     0.083553     0.115195
# 98     0.082750     0.114807
# 99     0.082000     0.114468
#
#                                         Pesos Cartera
# 0   {'Ibex': 0.0, 'S&P': -0.0, 'DJ': -0.0, 'NASDAQ...
# 1   {'Ibex': -0.0, 'S&P': -0.0, 'DJ': -0.0, 'NASDA...
# 2   {'Ibex': 0.0, 'S&P': -0.0, 'DJ': 0.0, 'NASDAQ_...
# 3   {'Ibex': -0.0, 'S&P': -0.0, 'DJ': -0.0, 'NASDA...
# 4   {'Ibex': 0.0, 'S&P': -0.0, 'DJ': -0.0, 'NASDAQ...
# ..                                                ...
# 95  {'Ibex': 0.0491, 'S&P': 0.1088, 'DJ': 0.1099, ...
# 96  {'Ibex': 0.0511, 'S&P': 0.1078, 'DJ': 0.1092, ...
# 97  {'Ibex': 0.0529, 'S&P': 0.1069, 'DJ': 0.1086, ...
# 98  {'Ibex': 0.0546, 'S&P': 0.106, 'DJ': 0.108, 'N...
# 99  {'Ibex': 0.0562, 'S&P': 0.1052, 'DJ': 0.1075, ...
#
# [100 rows x 3 columns]

# %% [markdown]
# # Perfecto ya tengo la frontera eficiente de las carteras que contienen los 12 indices, pa PowerBi que va.

# %%
#FronEfi.to_excel("C:/Users/Lorenzo/Desktop/Proyecto Final MARKOVITZ/FrontEfi.xlsx", index=False)

# %% [markdown]
# # Correlación

# %%
mergeo_indices = pd.concat([r_CAC, r_Ibex, r_DJ, r_EUROSTOXX50, r_FTSE, r_GDA, r_HANGSENG, r_NASDAQ100, r_NASDAQ_COMP, r_NIFTY50, r_NIKKEI225, r_SP500], axis=1)
mergeo_indices
# Out:
#                  CAC   Ibex_35  Dow_Jones  EURO_STOXX_50      FTSE       GDA  \
# Date
# 2013-06-05       NaN       NaN        NaN            NaN       NaN       NaN
# 2013-06-06       NaN       NaN        NaN            NaN       NaN       NaN
# 2013-06-07       NaN       NaN        NaN            NaN       NaN       NaN
# 2013-06-10       NaN       NaN        NaN            NaN       NaN       NaN
# 2013-06-11       NaN       NaN        NaN            NaN       NaN       NaN
# ...              ...       ...        ...            ...       ...       ...
# 2023-05-30  0.114542  0.048050  -0.005124       0.141517 -0.000093  0.100194
# 2023-05-31  0.105908  0.035007  -0.002481       0.111435 -0.015704  0.068938
# 2023-06-01  0.097992  0.050740   0.007568       0.125262 -0.012550  0.089103
# 2023-06-02  0.121103  0.054435   0.015474       0.135754  0.000947  0.111120
# 2023-06-05  0.099580  0.050613   0.022300       0.133101 -0.001013  0.124313
#
#             HANG_SENG_Index  NASDAQ_100  NASDAQ_Composite  NIFTY_50  \
# Date
# 2013-06-05              NaN         NaN               NaN       NaN
# 2013-06-06              NaN         NaN               NaN       NaN
# 2013-06-07              NaN         NaN               NaN       NaN
# 2013-06-10              NaN         NaN               NaN       NaN
# 2013-06-11              NaN         NaN               NaN       NaN
# ...                     ...         ...               ...       ...
# 2023-05-30        -0.119682    0.131970          0.073060  0.120631
# 2023-05-31        -0.148536    0.127510          0.070679  0.117587
# 2023-06-01        -0.144543    0.150868          0.092253  0.115767
# 2023-06-02        -0.101137    0.128268          0.075008  0.129002
# 2023-06-05        -0.117549    0.162895          0.104600  0.136804
#
#             NIKKEI_225   S&P_500
# Date
# 2013-06-05         NaN       NaN
# 2013-06-06         NaN       NaN
# 2013-06-07         NaN       NaN
# 2013-06-10         NaN       NaN
# 2013-06-11         NaN       NaN
# ...                ...       ...
# 2023-05-30    0.140953  0.011370
# 2023-05-31    0.126724  0.011539
# 2023-06-01    0.121983  0.029208
# 2023-06-02    0.129257  0.025270
# 2023-06-05    0.152930  0.042567
#
# [2604 rows x 12 columns]

# %%
correlacion = mergeo_indices.corr()
correlacion
# Out:
#                        CAC   Ibex_35  Dow_Jones  EURO_STOXX_50      FTSE  \
# CAC               1.000000  0.876441   0.775585       0.955106  0.786122
# Ibex_35           0.876441  1.000000   0.680857       0.899834  0.779177
# Dow_Jones         0.775585  0.680857   1.000000       0.770794  0.682138
# EURO_STOXX_50     0.955106  0.899834   0.770794       1.000000  0.705273
# FTSE              0.786122  0.779177   0.682138       0.705273  1.000000
# GDA               0.881295  0.808614   0.794435       0.943618  0.649315
# HANG_SENG_Index   0.554025  0.599600   0.764488       0.626831  0.466780
# NASDAQ_100        0.482223  0.368881   0.752473       0.576108  0.186067
# NASDAQ_Composite  0.527977  0.408585   0.797982       0.612787  0.249574
# NIFTY_50          0.742955  0.768361   0.784667       0.766598  0.652803
# NIKKEI_225        0.719111  0.649619   0.710530       0.773708  0.423065
# S&P_500           0.737249  0.610941   0.931804       0.760553  0.544108
#
#                        GDA  HANG_SENG_Index  NASDAQ_100  NASDAQ_Composite  \
# CAC               0.881295         0.554025    0.482223          0.527977
# Ibex_35           0.808614         0.599600    0.368881          0.408585
# Dow_Jones         0.794435         0.764488    0.752473          0.797982
# EURO_STOXX_50     0.943618         0.626831    0.576108          0.612787
# FTSE              0.649315         0.466780    0.186067          0.249574
# GDA               1.000000         0.713678    0.680162          0.715990
# HANG_SENG_Index   0.713678         1.000000    0.637297          0.672403
# NASDAQ_100        0.680162         0.637297    1.000000          0.991996
# NASDAQ_Composite  0.715990         0.672403    0.991996          1.000000
# NIFTY_50          0.711111         0.557051    0.565406          0.600647
# NIKKEI_225        0.828709         0.713697    0.682793          0.724454
# S&P_500           0.789922         0.649355    0.888652          0.909919
#
#                   NIFTY_50  NIKKEI_225   S&P_500
# CAC               0.742955    0.719111  0.737249
# Ibex_35           0.768361    0.649619  0.610941
# Dow_Jones         0.784667    0.710530  0.931804
# EURO_STOXX_50     0.766598    0.773708  0.760553
# FTSE              0.652803    0.423065  0.544108
# GDA               0.711111    0.828709  0.789922
# HANG_SENG_Index   0.557051    0.713697  0.649355
# NASDAQ_100        0.565406    0.682793  0.888652
# NASDAQ_Composite  0.600647    0.724454  0.909919
# NIFTY_50          1.000000    0.675981  0.791215
# NIKKEI_225        0.675981    1.000000  0.699362
# S&P_500           0.791215    0.699362  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(correlacion, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## ALTA CORRELACIÓN:
#
# ### (GLOBAL, USA) "TECH" NASDAQ 100  | 99% | NASDAQ COMPOSITE "COMBINED, HIGH TECH" (GLOBAL, USA)
# ### (EUROPA) "COMBINED" EURO STOXX 50 | 96% | CAC "COMBINED" (FRANCIA)
# ### (EUROPA) "COMBINED" EURO STOXX 50 | 94% | GDA "COMBINED" (ALEMANIA)
# ### (USA) "COMBINED" S&P 500 | 93% | DOW JONES "INDUSTRIAL" (USA)
# ### (USA) "COMBINED" S&P 500 | 91% | NASDAQ COMPOSITE "COMBINED, HIGH TECH" (GLOBAL, USA)
# ### (EUROPA) "COMBINED" EURO STOXX 50 | 90% | IBEX 35 "COMBINED" (ESPAÑA)

# %% [markdown]
# # DIBUJAMOS EL GRAFICO

# %%
df_transposed.plot.scatter(x = 'Volatilidad', y = 'Rentabilidad promedio');

# %% [markdown]
# ## COVARIANZA

# %%
rendi = mergeo_indices.dropna()

rendimientos = rendi.values

# Calcular la matriz de covarianza
covarianza = np.cov(rendimientos, rowvar=False)

print("Matriz de covarianza:")
print(covarianza)
# Out:
# Matriz de covarianza:
# [[0.02129363 0.02055668 0.01419424 0.02029772 0.01244522 0.01950267
#   0.01354944 0.01361906 0.01502882 0.01961428 0.01658354 0.0143469 ]
#  [0.02055668 0.02591309 0.01366853 0.0210344  0.01367492 0.01968092
#   0.01606806 0.01127883 0.01262185 0.02225052 0.01646015 0.01297419]
#  [0.01419424 0.01366853 0.01574633 0.01407941 0.00927853 0.01510373
#   0.01603699 0.01820325 0.01946033 0.01782432 0.01395766 0.0155891 ]
#  [0.02029772 0.0210344  0.01407941 0.02118987 0.01117442 0.02083524
#   0.01525096 0.0162917  0.01745187 0.02013417 0.01779909 0.01479846]
#  [0.01244522 0.01367492 0.00927853 0.01117442 0.01180866 0.01068169
#   0.00850309 0.00374534 0.00513984 0.01287813 0.00725358 0.00780938]
#  [0.01950267 0.01968092 0.01510373 0.02083524 0.01068169 0.0229963
#   0.01803456 0.02000722 0.02121114 0.01951262 0.01986767 0.01599428]
#  [0.01354944 0.01606806 0.01603699 0.01525096 0.00850309 0.01803456
#   0.02771597 0.02052461 0.02183442 0.01677375 0.01877943 0.01445737]
#  [0.01361906 0.01127883 0.01820325 0.0162917  0.00374534 0.02000722
#   0.02052461 0.03765803 0.03760489 0.01988379 0.02077422 0.02300695]
#  [0.01502882 0.01262185 0.01946033 0.01745187 0.00513984 0.02121114
#   0.02183442 0.03760489 0.03816011 0.02127252 0.02221186 0.02372979]
#  [0.01961428 0.02225052 0.01782432 0.02013417 0.01287813 0.01951262
#   0.01677375 0.01988379 0.02127252 0.03257816 0.01927917 0.01914087]
#  [0.01658354 0.01646015 0.01395766 0.01779909 0.00725358 0.01986767
#   0.01877943 0.02077422 0.02221186 0.01927917 0.02487525 0.01463103]
#  [0.0143469  0.01297419 0.0155891  0.01479846 0.00780938 0.01599428
#   0.01445737 0.02300695 0.02372979 0.01914087 0.01463103 0.01784407]]

# %%
std
# Out:
# [0.16085578056214825,
#  0.13399299198533746,
#  0.12580757068056478,
#  0.19472382429141202,
#  0.19318334272148377,
#  0.10842607985125395,
#  0.14614878794373087,
#  0.14542148121066262,
#  0.1509211832874728,
#  0.1574257033175363,
#  0.17983163340458547,
#  0.16555362089696174]

# %%
df_std = pd.DataFrame(std, columns=['STD'])
df_std
# Out:
#          STD
# 0   0.160856
# 1   0.133993
# 2   0.125808
# 3   0.194724
# 4   0.193183
# 5   0.108426
# 6   0.146149
# 7   0.145421
# 8   0.150921
# 9   0.157426
# 10  0.179832
# 11  0.165554

# %%
indexes = ['CAC', 'Ibex_35', 'Dow_Jones', 'EURO_STOXX_50', 'FTSE', 'GDA', 'HANG_SENG_Index', 'NASDAQ_100', 'NASDAQ_Composite', 'NIFTY_50', 'NIKKEI_225', 'S&P_500']
df_std['Indice'] = indexes
df_std = df_std.set_index('Indice')
df_std
# Out:
#                        STD
# Indice
# CAC               0.160856
# Ibex_35           0.133993
# Dow_Jones         0.125808
# EURO_STOXX_50     0.194724
# FTSE              0.193183
# GDA               0.108426
# HANG_SENG_Index   0.146149
# NASDAQ_100        0.145421
# NASDAQ_Composite  0.150921
# NIFTY_50          0.157426
# NIKKEI_225        0.179832
# S&P_500           0.165554

# %% [markdown]
# #### CAC	Ibex_35	Dow_Jones	EURO_STOXX_50	FTSE	GDA	HANG_SENG_Index	NASDAQ_100	NASDAQ_Composite	NIFTY_50	NIKKEI_225	S&P_500

# %%
covariance_df = correlacion * (df_std['STD'].values.reshape(-1, 1) * df_std['STD'].values)

covariance_df #Matriz de Varianzas y covarianzas (sin ponderar)
# Out:
#                        CAC   Ibex_35  Dow_Jones  EURO_STOXX_50      FTSE  \
# CAC               0.025875  0.018890   0.015695       0.029916  0.024428
# Ibex_35           0.018890  0.017954   0.011477       0.023478  0.020169
# Dow_Jones         0.015695  0.011477   0.015828       0.018883  0.016579
# EURO_STOXX_50     0.029916  0.023478   0.018883       0.037917  0.026531
# FTSE              0.024428  0.020169   0.016579       0.026531  0.037320
# GDA               0.015371  0.011748   0.010837       0.019923  0.013601
# HANG_SENG_Index   0.013025  0.011742   0.014056       0.017839  0.013179
# NASDAQ_100        0.011280  0.007188   0.013767       0.016314  0.005227
# NASDAQ_Composite  0.012817  0.008263   0.015151       0.018009  0.007276
# NIFTY_50          0.018814  0.016208   0.015541       0.023500  0.019853
# NIKKEI_225        0.020802  0.015653   0.016075       0.027093  0.014697
# S&P_500           0.019633  0.013553   0.019408       0.024518  0.017402
#
#                        GDA  HANG_SENG_Index  NASDAQ_100  NASDAQ_Composite  \
# CAC               0.015371         0.013025    0.011280          0.012817
# Ibex_35           0.011748         0.011742    0.007188          0.008263
# Dow_Jones         0.010837         0.014056    0.013767          0.015151
# EURO_STOXX_50     0.019923         0.017839    0.016314          0.018009
# FTSE              0.013601         0.013179    0.005227          0.007276
# GDA               0.011756         0.011309    0.010724          0.011716
# HANG_SENG_Index   0.011309         0.021359    0.013545          0.014831
# NASDAQ_100        0.010724         0.013545    0.021147          0.021772
# NASDAQ_Composite  0.011716         0.014831    0.021772          0.022777
# NIFTY_50          0.012138         0.012816    0.012944          0.014271
# NIKKEI_225        0.016159         0.018758    0.017856          0.019662
# S&P_500           0.014179         0.015711    0.021394          0.022735
#
#                   NIFTY_50  NIKKEI_225   S&P_500
# CAC               0.018814    0.020802  0.019633
# Ibex_35           0.016208    0.015653  0.013553
# Dow_Jones         0.015541    0.016075  0.019408
# EURO_STOXX_50     0.023500    0.027093  0.024518
# FTSE              0.019853    0.014697  0.017402
# GDA               0.012138    0.016159  0.014179
# HANG_SENG_Index   0.012816    0.018758  0.015711
# NASDAQ_100        0.012944    0.017856  0.021394
# NASDAQ_Composite  0.014271    0.019662  0.022735
# NIFTY_50          0.024783    0.019137  0.020621
# NIKKEI_225        0.019137    0.032339  0.020821
# S&P_500           0.020621    0.020821  0.027408

# %%
from scipy.optimize import curve_fit

# %%
rentabilidad = df_transposed['Rentabilidad promedio'].values
volatilidad = df_transposed['Volatilidad'].values

# %%
params, _ = curve_fit(markowitz_curve, rentabilidad, volatilidad, )
params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8408\536454846.py in <module>
# ----> 1 params, _ = curve_fit(markowitz_curve, rentabilidad, volatilidad, )
#       2 params
#
# NameError: name 'markowitz_curve' is not defined

# %%
# Obtener los parámetros ajustados
a, b, c = params

# Imprimir los parámetros ajustados
print("Parámetros ajustados:")
print("a:", a)
print("b:", b)
print("c:", c)
# Out:
# Parámetros ajustados:
# a: 4.982686918193157
# b: -0.5435024759357889
# c: 0.15339960423358942

# %%
x = np.linspace(min(rentabilidad), max(rentabilidad), 100)
y = markowitz_curve(x, a, b, c)

plt.plot(volatilidad, rentabilidad, 'o', label='Datos')
plt.plot(y, x)



plt.show();

# %% [markdown]
# # CURVE FIT SCIPY
